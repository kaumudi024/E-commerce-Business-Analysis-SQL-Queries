# %%
import pandas as pd
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
    ('customers.csv', 'customers'),
    ('orders.csv', 'orders'),
    ('sellers.csv', 'sellers'),
    ('products.csv', 'products'),
    ('geolocation.csv', 'geolocation'),
     ('order_items.csv', 'order_items'),
    ('payments.csv', 'payments')  # Added payments.csv for specific handling
]

# Connect to the MySQL database
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Lifeisdance24*',
    database='ecommerce'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = 'C:\\Users\\HP\\OneDrive\\Desktop\\ecommerce'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Replace NaN with None to handle SQL NULL
    df = df.where(pd.notnull(df), None)
    
    # Debugging: Check for NaN values
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    # Clean column names
    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    # Generate the CREATE TABLE statement with appropriate data types
    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)

    # Insert DataFrame data into the MySQL table
    for _, row in df.iterrows():
        # Convert row to tuple and handle NaN/None explicitly
        values = tuple(None if pd.isna(x) else x for x in row)
        sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(row))})"
        cursor.execute(sql, values)

    # Commit the transaction for the current CSV file
    conn.commit()

# Close the connection
conn.close()
# Out:
# Processing customers.csv
# NaN values before replacement:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Processing orders.csv
# NaN values before replacement:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# Processing sellers.csv
# NaN values before replacement:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
# Processing products.csv
# NaN values before replacement:
# product_id                      0
# product category              610
# product_name_length           610
# product_description_length    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
# Processing geolocation.csv
# NaN values before replacement:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Processing order_items.csv
# NaN values before replacement:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Processing payments.csv
# NaN values before replacement:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (9.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector

db = mysql.connector.connect(host = "localhost",
                             username = "root",
                             password = "Lifeisdance24*",
                             database = "ecommerce")
cur = db.cursor()

# %% [markdown]
# # List all unique cities where customers are located

# %%
query = """ select distinct customer_city from customers """

cur.execute(query)

data = cur.fetchall()

data
# Out:
# [('franca',),
#  ('sao bernardo do campo',),
#  ('sao paulo',),
#  ('mogi das cruzes',),
#  ('campinas',),
#  ('jaragua do sul',),
#  ('timoteo',),
#  ('curitiba',),
#  ('belo horizonte',),
#  ('montes claros',),
#  ('rio de janeiro',),
#  ('lencois paulista',),
#  ('caxias do sul',),
#  ('piracicaba',),
#  ('guarulhos',),
#  ('pacaja',),
#  ('florianopolis',),
#  ('aparecida de goiania',),
#  ('santo andre',),
#  ('goiania',),
#  ('cachoeiro de itapemirim',),
#  ('sao jose dos campos',),
#  ('sao roque',),
#  ('camacari',),
#  ('resende',),
#  ('sumare',),
#  ('novo hamburgo',),
#  ('sao luis',),
#  ('sao jose',),
#  ('santa barbara',),
#  ('ribeirao preto',),
#  ('ituiutaba',),
#  ('taquarituba',),
#  ('sao jose dos pinhais',),
#  ('barrinha',),
#  ('parati',),
#  ('dourados',),
#  ('trindade',),
#  ('cascavel',),
#  ('fortaleza',),
#  ('brasilia',),
#  ('pelotas',),
#  ('porto alegre',),
#  ('salto',),
#  ('jundiai',),
#  ('cacapava',),
#  ('sao vicente',),
#  ('uberlandia',),
#  ('botelhos',),
#  ('sao goncalo',),
#  ('araucaria',),
#  ('nova iguacu',),
#  ('areia branca',),
#  ('campos dos goytacazes',),
#  ('sao carlos',),
#  ('itajuba',),
#  ('cruz das almas',),
#  ('vassouras',),
#  ('feira de santana',),
#  ('niteroi',),
#  ('sobral',),
#  ('divinopolis',),
#  ('paraiba do sul',),
#  ('paulista',),
#  ('carapicuiba',),
#  ('bom principio',),
#  ('astolfo dutra',),
#  ('marialva',),
#  ('sao jose do rio preto',),
#  ('cabo frio',),
#  ('contagem',),
#  ('cafeara',),
#  ('sao joaquim da barra',),
#  ('foz do iguacu',),
#  ('suzano',),
#  ('timbo',),
#  ('camboriu',),
#  ('nova bassano',),
#  ('rio grande',),
#  ('braganca paulista',),
#  ('barra do garcas',),
#  ('embu',),
#  ('urussanga',),
#  ('silvianopolis',),
#  ('gameleiras',),
#  ('belem',),
#  ('pocos de caldas',),
#  ('santos',),
#  ('piracaia',),
#  ('sinop',),
#  ('guaruja',),
#  ('barueri',),
#  ('feliz',),
#  ('jambeiro',),
#  ('ipatinga',),
#  ('tupa',),
#  ('blumenau',),
#  ('moncoes',),
#  ('balneario camboriu',),
#  ('vargem grande',),
#  ('rio brilhante',),
#  ('eugenopolis',),
#  ('paulinia',),
#  ('apucarana',),
#  ('recife',),
#  ('osasco',),
#  ('valinhos',),
#  ('manaus',),
#  ('cidreira',),
#  ('santiago',),
#  ('sao sepe',),
#  ('alta floresta',),
#  ('jaboatao dos guararapes',),
#  ('ibatiba',),
#  ('hortolandia',),
#  ('cotia',),
#  ('macae',),
#  ('saudades',),
#  ('macapa',),
#  ('salto de pirapora',),
#  ('taboao da serra',),
#  ('bom jesus',),
#  ('santa cruz do rio pardo',),
#  ('diadema',),
#  ('santa ines',),
#  ('serrinha',),
#  ('votorantim',),
#  ('itatiaia',),
#  ('duque de caxias',),
#  ('varre-sai',),
#  ('vila velha',),
#  ('mangaratiba',),
#  ('atibaia',),
#  ('salvador',),
#  ('maceio',),
#  ('birigui',),
#  ('petropolis',),
#  ('sao pedro',),
#  ('jaguariaiva',),
#  ('franco da rocha',),
#  ('pindamonhangaba',),
#  ('irati',),
#  ('ribeira',),
#  ('barbacena',),
#  ('limoeiro',),
#  ('espigao do oeste',),
#  ('belford roxo',),
#  ('coronel fabriciano',),
#  ('itanhaem',),
#  ('bebedouro',),
#  ('americana',),
#  ('uba',),
#  ('arapongas',),
#  ('vinhedo',),
#  ('itajai',),
#  ('bauru',),
#  ('pradopolis',),
#  ('aripuana',),
#  ('guaratinga',),
#  ('ponta pora',),
#  ('aracatuba',),
#  ('volta redonda',),
#  ('maringa',),
#  ('araraquara',),
#  ('matipo',),
#  ('santo antonio da patrulha',),
#  ('barra mansa',),
#  ('diamantina',),
#  ('mairinque',),
#  ('capitao leonidas marques',),
#  ('sao sebastiao do paraiso',),
#  ('rosario do sul',),
#  ('itaguai',),
#  ('paraopeba',),
#  ('guarapuava',),
#  ('crisolita',),
#  ('pirai',),
#  ('linhares',),
#  ('agudos',),
#  ('sao joao de meriti',),
#  ('navegantes',),
#  ('pirassununga',),
#  ('faxinal dos guedes',),
#  ('criciuma',),
#  ('nova venecia',),
#  ('passo fundo',),
#  ('ibia',),
#  ('manhuacu',),
#  ('altamira',),
#  ('aperibe',),
#  ('cuiaba',),
#  ('canoas',),
#  ('cubatao',),
#  ('campo limpo paulista',),
#  ('cambe',),
#  ('itaquaquecetuba',),
#  ('sao caetano do sul',),
#  ('sao goncalo do rio abaixo',),
#  ('rolandia',),
#  ('tres coracoes',),
#  ('cacapava do sul',),
#  ('sao joao nepomuceno',),
#  ('leme',),
#  ('araras',),
#  ('cortes',),
#  ('brusque',),
#  ('montenegro',),
#  ('itaberai',),
#  ('santa rosa de viterbo',),
#  ('agua fria de goias',),
#  ('marau',),
#  ('curvelo',),
#  ('juiz de fora',),
#  ('mogi-guacu',),
#  ('guaratingueta',),
#  ('paranagua',),
#  ('lins',),
#  ('campo bom',),
#  ('sertaozinho',),
#  ('tres lagoas',),
#  ('jau',),
#  ('campos de julio',),
#  ('saquarema',),
#  ('artur nogueira',),
#  ('uaua',),
#  ('jandira',),
#  ('concordia',),
#  ('nova friburgo',),
#  ('sorocaba',),
#  ('ponte nova',),
#  ('araquari',),
#  ('muriae',),
#  ('nova lima',),
#  ('inhumas',),
#  ('italva',),
#  ('tres rios',),
#  ('santa maria',),
#  ('itagiba',),
#  ('paracatu',),
#  ('xaxim',),
#  ('laranjeiras do sul',),
#  ('itapiuna',),
#  ('formosa',),
#  ('ivoti',),
#  ('juazeiro',),
#  ('ponta grossa',),
#  ('campina grande',),
#  ('maua',),
#  ('salgueiro',),
#  ('lorena',),
#  ('toledo',),
#  ('sao pedro da aldeia',),
#  ('vianopolis',),
#  ('arapiraca',),
#  ('porto seguro',),
#  ('ariquemes',),
#  ('presidente getulio',),
#  ('rio negro',),
#  ('ribeirao pires',),
#  ('sao jose da coroa grande',),
#  ('agua doce do norte',),
#  ('anapolis',),
#  ('guararapes',),
#  ('farroupilha',),
#  ('almenara',),
#  ('rio das ostras',),
#  ('gravatai',),
#  ('brumado',),
#  ('marilia',),
#  ('itabira',),
#  ('claudia',),
#  ('para de minas',),
#  ('miguelopolis',),
#  ('terra roxa',),
#  ('araguari',),
#  ('lages',),
#  ('embu das artes',),
#  ('limeira',),
#  ('taubate',),
#  ('santa fe do sul',),
#  ('caieiras',),
#  ('carangola',),
#  ('chapada do norte',),
#  ('loanda',),
#  ('passa tres',),
#  ('aracoiaba da serra',),
#  ('itaborai',),
#  ('vitoria',),
#  ('sao bento do sul',),
#  ('indaiatuba',),
#  ('boituva',),
#  ('teresopolis',),
#  ('pinhalzinho',),
#  ('petrolina',),
#  ('natal',),
#  ('barreiras',),
#  ('januaria',),
#  ('ipiabas',),
#  ('firminopolis',),
#  ('joinville',),
#  ('mococa',),
#  ('valenca',),
#  ('sao miguel do oeste',),
#  ('jales',),
#  ('rio formoso',),
#  ('angra dos reis',),
#  ('alfredo chaves',),
#  ('itapetinga',),
#  ('gurupi',),
#  ('nucleo residencial pilar',),
#  ('coromandel',),
#  ('charqueada',),
#  ('itau de minas',),
#  ('ibiruba',),
#  ('bertioga',),
#  ('ipiau',),
#  ('matozinhos',),
#  ('teresina',),
#  ('entre rios',),
#  ('juina',),
#  ('mairipora',),
#  ('marechal candido rondon',),
#  ('avare',),
#  ('icem',),
#  ('sao sebastiao',),
#  ('serra',),
#  ('mirassol',),
#  ('taperuaba',),
#  ('alfenas',),
#  ('leopoldina',),
#  ('sao joao da boa vista',),
#  ('parnamirim',),
#  ('teixeira de freitas',),
#  ('joao pessoa',),
#  ('chacara',),
#  ('rio novo do sul',),
#  ('guapore',),
#  ('rio branco',),
#  ('ferraz de vasconcelos',),
#  ('petrolandia',),
#  ('araruna',),
#  ('gravata',),
#  ('alegre',),
#  ('londrina',),
#  ('senhor do bonfim',),
#  ('santana de parnaiba',),
#  ('piratininga',),
#  ('monte carmelo',),
#  ('ipiranga',),
#  ('jacarei',),
#  ('picos',),
#  ('una',),
#  ('taguai',),
#  ('peabiru',),
#  ('conquista',),
#  ('bicas',),
#  ('forquilha',),
#  ('guaicara',),
#  ('santa vitoria',),
#  ('adamantina',),
#  ('rio claro',),
#  ('sao jose de uba',),
#  ('sorriso',),
#  ('aracaju',),
#  ('conselheiro lafaiete',),
#  ('taguatinga',),
#  ('tiangua',),
#  ('paranaiba',),
#  ('david canabarro',),
#  ('itarare',),
#  ('cajueiro',),
#  ('cruzeiro',),
#  ('santa cruz do sul',),
#  ('presidente epitacio',),
#  ('castanhal',),
#  ('cariacica',),
#  ('bom jesus dos perdoes',),
#  ('urucurituba',),
#  ('olinda',),
#  ('sao jose do rio pardo',),
#  ('guapimirim',),
#  ('vargem grande paulista',),
#  ('chapeco',),
#  ('videira',),
#  ('canapi',),
#  ('pontal do parana',),
#  ('bento goncalves',),
#  ('caceres',),
#  ('bituruna',),
#  ('sao bento do sapucai',),
#  ('mage',),
#  ('forquilhinha',),
#  ('itaberaba',),
#  ('gramado',),
#  ('guacui',),
#  ('pato branco',),
#  ('itanhem',),
#  ('palmas',),
#  ('bage',),
#  ('francisco morato',),
#  ('cosmopolis',),
#  ('carmo',),
#  ('armacao dos buzios',),
#  ('santa maria da vitoria',),
#  ('pedro leopoldo',),
#  ('tres marias',),
#  ('santo antonio de padua',),
#  ('porto feliz',),
#  ('gaspar',),
#  ('palhoca',),
#  ('pouso alegre',),
#  ('guaiuba',),
#  ('fraiburgo',),
#  ('aurea',),
#  ('botucatu',),
#  ('corumba',),
#  ('cajamar',),
#  ('queimados',),
#  ('sao jorge do ivai',),
#  ('nova laranjeiras',),
#  ('guaxupe',),
#  ('osvaldo cruz',),
#  ('ivora',),
#  ('anaurilandia',),
#  ('caraguatatuba',),
#  ('regeneracao',),
#  ('bilac',),
#  ('faxinal',),
#  ('pedro velho',),
#  ('uberaba',),
#  ('viamao',),
#  ('cachoeira de minas',),
#  ('coelho neto',),
#  ('itajobi',),
#  ('carmo do rio claro',),
#  ('marica',),
#  ('campo novo do parecis',),
#  ('boa vista',),
#  ('ipameri',),
#  ('carlos barbosa',),
#  ('anicuns',),
#  ('rio bananal',),
#  ('lavras da mangabeira',),
#  ('balsamo',),
#  ('guariba',),
#  ('sao vendelino',),
#  ('campo mourao',),
#  ('aracati',),
#  ('santo antonio do descoberto',),
#  ('santo amaro da imperatriz',),
#  ('betim',),
#  ('vicosa',),
#  ('dom eliseu',),
#  ('campo largo',),
#  ('santa rosa de lima',),
#  ('quissama',),
#  ('mirandopolis',),
#  ('itapevi',),
#  ('francisco beltrao',),
#  ("dias d'avila",),
#  ('novo horizonte',),
#  ('poa',),
#  ('querencia',),
#  ('campo grande',),
#  ('pedreira',),
#  ('pariquera-acu',),
#  ('itabaianinha',),
#  ('pitangui',),
#  ('araruama',),
#  ('campo formoso',),
#  ('guanambi',),
#  ('itapolis',),
#  ('pederneiras',),
#  ('itabirito',),
#  ('itaipava',),
#  ('arroio do sal',),
#  ('glaura',),
#  ('lagoa vermelha',),
#  ('mantena',),
#  ('peruibe',),
#  ('tubarao',),
#  ('bonfim',),
#  ('alvorada',),
#  ('patrocinio',),
#  ('mineiros',),
#  ('itabuna',),
#  ('tijucas',),
#  ('santo antonio de jesus',),
#  ('canarana',),
#  ('itapecerica da serra',),
#  ('nova prata do iguacu',),
#  ('treze tilias',),
#  ('anchieta',),
#  ('quatigua',),
#  ('iturama',),
#  ('tres de maio',),
#  ('santa rita do passa quatro',),
#  ('porto esperidiao',),
#  ('bonfim paulista',),
#  ('cajuru',),
#  ('cacador',),
#  ('paragominas',),
#  ('boa esperanca do sul',),
#  ('tres pontas',),
#  ('juazeiro do norte',),
#  ('bambui',),
#  ('comendador levy gasparian',),
#  ('sao miguel do aleixo',),
#  ('palmeira dos indios',),
#  ('cerquilho',),
#  ('saudade do iguacu',),
#  ('ipaussu',),
#  ('alto paraiso de goias',),
#  ('santa isabel',),
#  ('quirinopolis',),
#  ('caruaru',),
#  ('casimiro de abreu',),
#  ('chavantes',),
#  ('ecoporanga',),
#  ('cachoeira paulista',),
#  ('rio verde',),
#  ('maracanau',),
#  ('canoinhas',),
#  ('ituverava',),
#  ('buriti dos lopes',),
#  ('rio do antonio',),
#  ('guaranta',),
#  ('santa luzia',),
#  ('tucurui',),
#  ('paranavai',),
#  ('pinhais',),
#  ('governador valadares',),
#  ('trajano de moraes',),
#  ('caete',),
#  ('abaetetuba',),
#  ('lavras',),
#  ('coronel joao sa',),
#  ('divino',),
#  ('macaubas',),
#  ('lucelia',),
#  ('brejo da madre de deus',),
#  ('carai',),
#  ('corbelia',),
#  ('varginha',),
#  ('ouro preto',),
#  ('prado',),
#  ('colniza',),
#  ('piuma',),
#  ('rancharia',),
#  ('barretos',),
#  ('eunapolis',),
#  ('floresta',),
#  ('sao jose do norte',),
#  ('rio bonito',),
#  ('vargem bonita',),
#  ('monte mor',),
#  ('valente',),
#  ('balsas',),
#  ('nhandeara',),
#  ('lauro de freitas',),
#  ('osorio',),
#  ('machado',),
#  ('sao leopoldo',),
#  ('soledade',),
#  ('assis',),
#  ('guarapari',),
#  ('santo antonio do caiua',),
#  ('esteio',),
#  ('cambuci',),
#  ('campina grande do sul',),
#  ('baixo guandu',),
#  ('fernao',),
#  ('ibitinga',),
#  ('santa cruz das palmeiras',),
#  ('vila muriqui',),
#  ('sao mateus',),
#  ('piracuruca',),
#  ('cordeiro',),
#  ('cachoeira do sul',),
#  ('barra do pirai',),
#  ('castro',),
#  ('ico',),
#  ('sete lagoas',),
#  ('itumbiara',),
#  ('aluminio',),
#  ('jatai',),
#  ('frederico westphalen',),
#  ('goioere',),
#  ('sao jose da tapera',),
#  ('porto uniao',),
#  ('cocalinho',),
#  ('curitibanos',),
#  ('campos novos',),
#  ('ubatuba',),
#  ('monte santo de minas',),
#  ('ribeirao das neves',),
#  ('sao simao',),
#  ('urutai',),
#  ('itaobim',),
#  ('liberdade',),
#  ('arcos',),
#  ('ribeirao',),
#  ('patos de minas',),
#  ('penapolis',),
#  ('eusebio',),
#  ('cordeiros',),
#  ('victor graeff',),
#  ('santa rita do araguaia',),
#  ('poxoreu',),
#  ('ananas',),
#  ('conceicao dos ouros',),
#  ('alagoinhas',),
#  ('sao joao da barra',),
#  ('lindoia',),
#  ('bonfinopolis',),
#  ('ibiam',),
#  ('morungaba',),
#  ('andradina',),
#  ('tatui',),
#  ('mata verde',),
#  ('cornelio procopio',),
#  ('itapipoca',),
#  ('queluz',),
#  ('godoy moreira',),
#  ('iracemapolis',),
#  ('buritizeiro',),
#  ('xique-xique',),
#  ('uruacu',),
#  ('japi',),
#  ('itauna',),
#  ('sao francisco de assis',),
#  ('pitangueiras',),
#  ('ze doca',),
#  ('dracena',),
#  ('cachoeiras de macacu',),
#  ('barauna',),
#  ('formiga',),
#  ('rodeio',),
#  ('jequie',),
#  ('juvenilia',),
#  ('poco fundo',),
#  ('amparo',),
#  ('lauro muller',),
#  ('japeri',),
#  ('ourinhos',),
#  ('lagoa dos gatos',),
#  ('embu-guacu',),
#  ('nossa senhora do remedio',),
#  ('tambau',),
#  ('orlandia',),
#  ('bananeiras',),
#  ('sao joao do manhuacu',),
#  ('sarandi',),
#  ('congonhas',),
#  ('boa esperanca',),
#  ('sandolandia',),
#  ('garca',),
#  ('descalvado',),
#  ('guaracai',),
#  ('aruana',),
#  ('inga',),
#  ('taio',),
#  ('gaurama',),
#  ('praia grande',),
#  ('janauba',),
#  ('nova monte verde',),
#  ('mongagua',),
#  ('monte alto',),
#  ('sao joao do piaui',),
#  ('primavera do leste',),
#  ('seropedica',),
#  ('indaial',),
#  ('teofilo otoni',),
#  ('santa terezinha',),
#  ('planaltina',),
#  ('caravelas',),
#  ('muritiba',),
#  ('itatiba',),
#  ('piumhii',),
#  ('pitanga',),
#  ('capelinha',),
#  ('ipero',),
#  ('tarabai',),
#  ('aparecida do taboado',),
#  ('maioba',),
#  ('monnerat',),
#  ('sao lourenco do sul',),
#  ('biguacu',),
#  ('venda nova do imigrante',),
#  ('arapoti',),
#  ('fazenda rio grande',),
#  ('senges',),
#  ('aracruz',),
#  ('canela',),
#  ('porto franco',),
#  ('veranopolis',),
#  ('candiota',),
#  ('carmo do paranaiba',),
#  ('itacare',),
#  ('desembargador otoni',),
#  ('joanopolis',),
#  ('registro',),
#  ('ipiranga do norte',),
#  ('felipe guerra',),
#  ('dumont',),
#  ('itapetininga',),
#  ('bom despacho',),
#  ('lagoa santa',),
#  ('estacao',),
#  ('panorama',),
#  ('palmares',),
#  ('prata',),
#  ('santa adelia',),
#  ('iguaba grande',),
#  ('sarzedo',),
#  ('dourado',),
#  ('alcinopolis',),
#  ('limoeiro do norte',),
#  ('ibiraci',),
#  ('ilhabela',),
#  ('icara',),
#  ('paiva',),
#  ('batatais',),
#  ('formoso do araguaia',),
#  ('itapaci',),
#  ('fernandopolis',),
#  ('miguel pereira',),
#  ('tocos',),
#  ('campos do jordao',),
#  ('catalao',),
#  ('sao jose da lapa',),
#  ('marituba',),
#  ('arapora',),
#  ('turvo',),
#  ('rubiataba',),
#  ('guaruja do sul',),
#  ('pedra bela',),
#  ('perdizes',),
#  ('jesuania',),
#  ('antonio carlos',),
#  ('itapecerica',),
#  ('monte belo',),
#  ('mossoro',),
#  ('piraju',),
#  ('encruzilhada do sul',),
#  ('igaratinga',),
#  ('sao luis de montes belos',),
#  ('santa rosa',),
#  ('lagoinha',),
#  ('redentora',),
#  ('cuite',),
#  ('coxim',),
#  ('lucas do rio verde',),
#  ('ibirataia',),
#  ('olimpia',),
#  ('cedro',),
#  ('mario campos',),
#  ('umuarama',),
#  ('nova xavantina',),
#  ('sao borja',),
#  ('aguai',),
#  ('itapira',),
#  ('uniao da vitoria',),
#  ('nova odessa',),
#  ('itapuranga',),
#  ('nova cruz',),
#  ('apuiares',),
#  ('almirante tamandare',),
#  ('correia pinto',),
#  ('itamarandiba',),
#  ('juscimeira',),
#  ('ipora',),
#  ('cedro de sao joao',),
#  ("santa barbara d'oeste",),
#  ('sao joao da urtiga',),
#  ('valparaiso de goias',),
#  ('jussara',),
#  ('capao da canoa',),
#  ('araxa',),
#  ('campo belo',),
#  ('monte aprazivel',),
#  ('bom jesus do querendo',),
#  ('socorro',),
#  ('catanduva',),
#  ('monte castelo',),
#  ('tabatinga',),
#  ('bayeux',),
#  ('ijui',),
#  ('tangara da serra',),
#  ('campos borges',),
#  ('palma',),
#  ('minacu',),
#  ('miracema',),
#  ('taruma',),
#  ('sao francisco do sul',),
#  ('cedral',),
#  ('camaragibe',),
#  ('lajeado',),
#  ('cerqueira cesar',),
#  ('frutal',),
#  ('igarata',),
#  ('novo gama',),
#  ('sapucaia do sul',),
#  ('juquitiba',),
#  ('terra boa',),
#  ('joao monlevade',),
#  ('porangatu',),
#  ('formosa da serra negra',),
#  ('rafard',),
#  ('rainha do mar',),
#  ('pontal',),
#  ('rio do sul',),
#  ('nilopolis',),
#  ('maracaju',),
#  ('santo augusto',),
#  ('banabuiu',),
#  ('buenopolis',),
#  ('barbalha',),
#  ('quintana',),
#  ('chorrocho',),
#  ('votuporanga',),
#  ('poco verde',),
#  ('cipo-guacu',),
#  ('santarem',),
#  ('santa clara do sul',),
#  ('ibiuna',),
#  ('capivari',),
#  ('arraias',),
#  ('patos',),
#  ('sao francisco do guapore',),
#  ('vitoria da conquista',),
#  ('urucuca',),
#  ('vacaria',),
#  ('campos altos',),
#  ('nossa senhora do socorro',),
#  ('cruzeiro do sul',),
#  ('cataguases',),
#  ('varzea grande',),
#  ('santa rita do sapucai',),
#  ('jaboticabal',),
#  ('ilha comprida',),
#  ('brasilia de minas',),
#  ('moreno',),
#  ('capanema',),
#  ('tombos',),
#  ('espumoso',),
#  ('ouro branco',),
#  ('valenca do piaui',),
#  ('igrejinha',),
#  ('engenheiro coelho',),
#  ('parauapebas',),
#  ('afonso claudio',),
#  ('sao bernardo',),
#  ('salto do jacui',),
#  ('pires do rio',),
#  ('astorga',),
#  ('medina',),
#  ('porto ferreira',),
#  ('aracariguama',),
#  ('hidrolandia',),
#  ('virginopolis',),
#  ('soledade de minas',),
#  ('casca',),
#  ('sapiranga',),
#  ('angatuba',),
#  ('ibirapua',),
#  ('itupeva',),
#  ('espera feliz',),
#  ('penedo',),
#  ('ibirite',),
#  ('miracatu',),
#  ('francisco santos',),
#  ('paracambi',),
#  ('cardoso',),
#  ('floriano',),
#  ('rondonopolis',),
#  ('barra de sao francisco',),
#  ('lavinia',),
#  ('guajara-mirim',),
#  ('guimaraes',),
#  ('sao tome',),
#  ('medianeira',),
#  ('conceicao das pedras',),
#  ('rinopolis',),
#  ('capim grosso',),
#  ('guaira',),
#  ('euclides da cunha paulista',),
#  ('lagoa da prata',),
#  ('nanuque',),
#  ('luis antonio',),
#  ('senador firmino',),
#  ('viradouro',),
#  ('itabera',),
#  ('cambara',),
#  ('sananduva',),
#  ('tapera',),
#  ('tupaciguara',),
#  ('colombo',),
#  ('ananindeua',),
#  ('coribe',),
#  ('rio doce',),
#  ('mogi mirim',),
#  ('tocos do moji',),
#  ('beberibe',),
#  ('formosa do rio preto',),
#  ('claudio',),
#  ('rio paranaiba',),
#  ('humberto de campos',),
#  ('camocim de sao felix',),
#  ('santo antonio de posse',),
#  ('mesquita',),
#  ('passa quatro',),
#  ('belo oriente',),
#  ('alto araguaia',),
#  ('igarassu',),
#  ('porto velho',),
#  ('cajazeiras',),
#  ('garopaba',),
#  ('rio azul',),
#  ('dois corregos',),
#  ('sooretama',),
#  ('cruzeiro do oeste',),
#  ('nazare paulista',),
#  ('riversul',),
#  ('iguaracu',),
#  ('maracas',),
#  ('parana',),
#  ('reboucas',),
#  ('ametista do sul',),
#  ('itu',),
#  ('cacu',),
#  ('vespasiano',),
#  ('lindolfo collor',),
#  ('sao lourenco',),
#  ('santana do sobrado',),
#  ('cafelandia',),
#  ('ibiapina',),
#  ('schroeder',),
#  ('sao joao do oriente',),
#  ('matao',),
#  ('itanhandu',),
#  ('santo angelo',),
#  ('capinopolis',),
#  ('colatina',),
#  ('nova mutum',),
#  ('munhoz de melo',),
#  ('ibate',),
#  ('unai',),
#  ('medeiros neto',),
#  ('anta',),
#  ('ouroeste',),
#  ('central',),
#  ('nova independencia',),
#  ('itapema',),
#  ('sao jose do cedro',),
#  ('camutanga',),
#  ('ipumirim',),
#  ('cristalia',),
#  ('andira',),
#  ('panelas',),
#  ('comodoro',),
#  ('domingos martins',),
#  ('tangua',),
#  ('sao gotardo',),
#  ('araguaina',),
#  ('ilheus',),
#  ('louveira',),
#  ('imbituba',),
#  ('ouricuri',),
#  ('itatinga',),
#  ('santo cristo',),
#  ("arraial d'ajuda",),
#  ('piracanjuba',),
#  ('russas',),
#  ('lambari',),
#  ('vargem alta',),
#  ('sacra familia do tingua',),
#  ('assis chateaubriand',),
#  ('lago da pedra',),
#  ('unistalda',),
#  ('sao joao evangelista',),
#  ('paramirim',),
#  ('goias',),
#  ('paracuru',),
#  ('cruz alta',),
#  ('presidente bernardes',),
#  ('pains',),
#  ('sao goncalo do rio preto',),
#  ('jacinto machado',),
#  ('sobralia',),
#  ('maraba',),
#  ('paraibuna',),
#  ('toropi',),
#  ('jauru',),
#  ('cristalandia',),
#  ('castelo do piaui',),
#  ('ibipora',),
#  ('presidente dutra',),
#  ('vera cruz',),
#  ('paulo frontin',),
#  ...]

# %% [markdown]
# # Count the number of orders placed in 2017

# %%
query = """ select count(order_id) from orders where year(order_purchase_timestamp) = 2017  """

cur.execute(query)

data = cur.fetchall()

"total orders placed in 2017 are", data[0][0]
# Out:
# ('total orders placed in 2017 are', 90202)

# %% [markdown]
# # Find the total sales per category

# %%
query = """ select products.product_category category, 
round(sum(payments.payment_value),2)
from products join order_items
on products.product_id = order_items.product_id
join payments
on payments.order_id = order_items.order_id
group by category
"""

cur.execute(query)

data = cur.fetchall()

data
# Out:
# [('perfumery', 4053909.28),
#  ('Furniture Decoration', 11441411.13),
#  ('telephony', 3895056.41),
#  ('bed table bath', 13700429.37),
#  ('automotive', 6818354.65),
#  ('computer accessories', 12682643.57),
#  ('housewares', 8758065.04),
#  ('babies', 4318765.28),
#  ('toys', 4952301.52),
#  ('Furniture office', 5174611.9),
#  ('Cool Stuff', 6237584.0),
#  ('HEALTH BEAUTY', 13258984.96),
#  ('pet Shop', 2490151.76),
#  ('General Interest Books', 517558.08),
#  ('stationary store', 2539520.56),
#  ('Watches present', 11433733.43),
#  ('PCs', 2232972.39),
#  ('climatization', 729365.28),
#  ('Construction Tools Construction', 1931805.04),
#  ('sport leisure', 11137020.47),
#  ('Bags Accessories', 1497210.32),
#  ('electronics', 2078856.8),
#  ('Casa Construcao', 1093162.32),
#  ('Games consoles', 1563843.03),
#  ('Fashion Bags and Accessories', 1745266.24),
#  ('home appliances', 764258.16),
#  ('Garden tools', 6706246.01),
#  ('Agro Industria e Comercio', 949844.88),
#  (None, 2022413.68),
#  ('audio', 482596.96),
#  ('technical books', 199323.52),
#  ('Construction Tools Garden', 339155.28),
#  ('Market Place', 362687.36),
#  ('musical instruments', 1864592.97),
#  ('Drink foods', 218317.84),
#  ('SIGNALIZATION AND SAFETY', 547904.4),
#  ('Furniture Kitchen Service Area Dinner and Garden', 597287.84),
#  ('song', 55211.44),
#  ('HOUSE PASTALS OVEN AND CAFE', 409834.56),
#  ('fixed telephony', 1656082.08),
#  ('Room Furniture', 1089110.16),
#  ('Construction Tools Tools', 168552.56),
#  ('House comfort', 674632.48),
#  ('Industry Commerce and Business', 453966.08),
#  ('Construction Tools Illumination', 581699.84),
#  ('ELECTRICES 2', 996507.69),
#  ('Fashion Calcados', 259381.92),
#  ('Fashion Underwear and Beach Fashion', 101716.32),
#  ('electrostile', 1804675.04),
#  ('foods', 371429.36),
#  ('IMAGE IMPORT TABLETS', 80343.44),
#  ('Art', 247943.44),
#  ('drinks', 571437.21),
#  ('Arts and Crafts', 18609.36),
#  ("Fashion Women's Clothing", 40876.96),
#  ('flowers', 17704.08),
#  ('Christmas articles', 151958.16),
#  ("Fashion Men's Clothing", 138327.84),
#  ('Fashion Sport', 29167.36),
#  ('CONSTRUCTION SECURITY TOOLS', 525528.24),
#  ('Furniture', 252791.52),
#  ('Imported books', 53615.12),
#  ('party articles', 47730.48),
#  ('cine photo', 76242.56),
#  ('Blu Ray DVDs', 63482.24),
#  ('Hygiene diapers', 33770.0),
#  ('House Comfort 2', 13684.32),
#  ('CITTE AND UPHACK FURNITURE', 47988.32),
#  ('Kitchen portable and food coach', 34685.2),
#  ('cds music dvds', 9595.44),
#  ('La Cuisine', 23308.24),
#  ("Fashion Children's Clothing", 6285.36),
#  ('PC Gamer', 17395.44),
#  ('insurance and services', 2596.08)]

# %% [markdown]
# # Calculate the percentage of orders that were paid in installments

# %%
query = """ select (sum(case when payment_installments >= 1 then 1 else 0 end))/count(*)*100 from payments"""

cur.execute(query)

data = cur.fetchall()

"percentage of orders that were paid in installments is ", data[0][0]
# Out:
# ('percentage of orders that were paid in installments is ', Decimal('99.9981'))

# %% [markdown]
# # Count the number of customers from each state

# %%
query = """ select customer_state, count(customer_id)
from customers group by customer_state
"""

cur.execute(query)

data = cur.fetchall()

df = pd.DataFrame(data, columns = ["State", "Customer_Count"])
df = df.sort_values(by = "Customer_Count", ascending = False) 
plt.figure(figsize = (9,4))
plt.bar(df["State"], df["Customer_Count"])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Calculate the number of orders per month 2018

# %%
query = """ select monthname(order_purchase_timestamp) months, count(order_id) 
from orders where year(order_purchase_timestamp) = 2018
group by months
"""

cur.execute(query)

data = cur.fetchall()


df = pd.DataFrame(data, columns = ["months", "order_counts"])
df
o = ["January", "February","March","April", "May", "June","July","August", "September", "October"]
ax =sns.barplot(x = df["months"],y =  df["order_counts"], data = df, order = o)
plt.xticks(rotation = 45)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
#  # Find the average number of products per order, grouped by customer city.

# %%
query = """ with count_per_order as
(select orders.order_id, orders.customer_id, count(order_items.order_id) as oc
from orders join order_items
on orders.order_id = order_items.order_id
group by orders.order_Id, orders.customer_id)

select customers.customer_city, round(avg(count_per_order.oc),2) average_orders
from customers join count_per_order
on customers.customer_id = count_per_order.customer_id
group by customers.customer_city order by average_orders
"""

cur.execute(query)

data = cur.fetchall()
data
# Out:
# [('serranopolis', Decimal('4.00')),
#  ('fortim', Decimal('4.00')),
#  ('cairu', Decimal('4.00')),
#  ('epitaciolandia', Decimal('4.00')),
#  ('urucania', Decimal('4.00')),
#  ('porto calvo', Decimal('4.00')),
#  ('ipupiara', Decimal('4.00')),
#  ('americo de campos', Decimal('4.00')),
#  ('sao joao do sobrado', Decimal('4.00')),
#  ('bora', Decimal('4.00')),
#  ('humberto de campos', Decimal('4.00')),
#  ('passagem', Decimal('4.00')),
#  ('barrocas', Decimal('4.00')),
#  ('matrincha', Decimal('4.00')),
#  ('campina das missoes', Decimal('4.00')),
#  ('jardim de piranhas', Decimal('4.00')),
#  ('coronel sapucaia', Decimal('4.00')),
#  ('jacigua', Decimal('4.00')),
#  ('padre gonzales', Decimal('4.00')),
#  ('major porto', Decimal('4.00')),
#  ('minduri', Decimal('4.00')),
#  ('itaparica', Decimal('4.00')),
#  ('sinimbu', Decimal('4.00')),
#  ('piacu', Decimal('4.00')),
#  ('santo antonio do leverger', Decimal('4.00')),
#  ('ponte alta do norte', Decimal('4.00')),
#  ('boa esperanca do iguacu', Decimal('4.00')),
#  ('jardim olinda', Decimal('4.00')),
#  ('tecainda', Decimal('4.00')),
#  ('alexandria', Decimal('4.00')),
#  ('filadelfia', Decimal('4.00')),
#  ('amanari', Decimal('4.00')),
#  ('queiroz', Decimal('4.00')),
#  ('purilandia', Decimal('4.00')),
#  ('sao jose do goiabal', Decimal('4.00')),
#  ('felixlandia', Decimal('4.00')),
#  ('tomar do geru', Decimal('4.00')),
#  ('vicente dutra', Decimal('4.00')),
#  ('anhumas', Decimal('4.00')),
#  ('natividade da serra', Decimal('4.00')),
#  ('santa rita de jacutinga', Decimal('4.00')),
#  ('bertolinia', Decimal('4.00')),
#  ('mariental', Decimal('4.00')),
#  ('nova padua', Decimal('4.00')),
#  ('ibitita', Decimal('4.00')),
#  ('cipo', Decimal('4.00')),
#  ('aramina', Decimal('4.00')),
#  ('guassusse', Decimal('4.00')),
#  ('sapopema', Decimal('4.00')),
#  ('sao francisco do gloria', Decimal('4.00')),
#  ('santa teresinha', Decimal('4.00')),
#  ('mato rico', Decimal('4.00')),
#  ('pinhal da serra', Decimal('4.00')),
#  ('nantes', Decimal('4.00')),
#  ('picada cafe', Decimal('4.00')),
#  ('canto do buriti', Decimal('4.00')),
#  ('bom jardim de goias', Decimal('4.00')),
#  ('murici', Decimal('4.00')),
#  ('fruta de leite', Decimal('4.00')),
#  ('praia norte', Decimal('4.00')),
#  ('pedras altas', Decimal('4.00')),
#  ('palmeirinha', Decimal('4.00')),
#  ('machadinho', Decimal('4.00')),
#  ('bossoroca', Decimal('4.00')),
#  ('boquim', Decimal('4.00')),
#  ('corrego fundo', Decimal('4.00')),
#  ('carmesia', Decimal('4.00')),
#  ('presidente janio quadros', Decimal('4.00')),
#  ('santa leopoldina', Decimal('4.00')),
#  ('guarapua', Decimal('4.00')),
#  ('piracema', Decimal('4.00')),
#  ('buriti alegre', Decimal('4.00')),
#  ('pedra menina', Decimal('4.00')),
#  ('galinhos', Decimal('4.00')),
#  ('retirolandia', Decimal('4.00')),
#  ('florania', Decimal('4.00')),
#  ('boa vista do cadeado', Decimal('4.00')),
#  ('feliz natal', Decimal('4.00')),
#  ('durande', Decimal('4.00')),
#  ('santo inacio', Decimal('4.00')),
#  ('fenix', Decimal('4.00')),
#  ('saude', Decimal('4.00')),
#  ('cristopolis', Decimal('4.00')),
#  ('mariapolis', Decimal('4.00')),
#  ('araguana', Decimal('4.00')),
#  ('caraibas', Decimal('4.00')),
#  ('porto rico', Decimal('4.00')),
#  ('ipiranga de goias', Decimal('4.00')),
#  ('calcado', Decimal('4.00')),
#  ('congonhinhas', Decimal('4.00')),
#  ('monte santo', Decimal('4.00')),
#  ('montadas', Decimal('4.00')),
#  ('girau do ponciano', Decimal('4.00')),
#  ('ipueira', Decimal('4.00')),
#  ('juripiranga', Decimal('4.00')),
#  ('brasilandia de minas', Decimal('4.00')),
#  ('aguas mornas', Decimal('4.00')),
#  ('capao da porteira', Decimal('4.00')),
#  ('sacra familia do tingua', Decimal('4.00')),
#  ('nazare da mata', Decimal('4.00')),
#  ('passos maia', Decimal('4.00')),
#  ('ibitiara', Decimal('4.00')),
#  ('nova guataporanga', Decimal('4.00')),
#  ('mampituba', Decimal('4.00')),
#  ('barao', Decimal('4.00')),
#  ('jacuipe', Decimal('4.00')),
#  ('jacareacanga', Decimal('4.00')),
#  ('irai', Decimal('4.00')),
#  ('charrua', Decimal('4.00')),
#  ('salto grande', Decimal('4.00')),
#  ('nonoai', Decimal('4.00')),
#  ('sao patricio', Decimal('4.00')),
#  ('fonseca', Decimal('4.00')),
#  ('guaraquecaba', Decimal('4.00')),
#  ('sao pedro do butia', Decimal('4.00')),
#  ('igarape-miri', Decimal('4.00')),
#  ('isaias coelho', Decimal('4.00')),
#  ('ipaporanga', Decimal('4.00')),
#  ('angelica', Decimal('4.00')),
#  ('alfredo marcondes', Decimal('4.00')),
#  ("nova brasilandia d'oeste", Decimal('4.00')),
#  ('sao domingos do araguaia', Decimal('4.00')),
#  ('paial', Decimal('4.00')),
#  ('porto lucena', Decimal('4.00')),
#  ('getulina', Decimal('4.00')),
#  ('angustura', Decimal('4.00')),
#  ("olhos d'agua", Decimal('4.00')),
#  ('itacurussa', Decimal('4.00')),
#  ('sao francisco do brejao', Decimal('4.00')),
#  ('uniao do sul', Decimal('4.00')),
#  ('sao luis do quitunde', Decimal('4.00')),
#  ('morro do pilar', Decimal('4.00')),
#  ('teixeira', Decimal('4.00')),
#  ('acucena', Decimal('4.00')),
#  ('divinesia', Decimal('4.00')),
#  ('monte alverne', Decimal('4.00')),
#  ('campina do monte alegre', Decimal('4.00')),
#  ('ipecaeta', Decimal('4.00')),
#  ('arara', Decimal('4.00')),
#  ('vicosa do ceara', Decimal('4.00')),
#  ('mauriti', Decimal('4.00')),
#  ('ipuiuna', Decimal('4.00')),
#  ('alianca', Decimal('4.00')),
#  ('osvaldo kroeff', Decimal('4.00')),
#  ('conceicao do formoso', Decimal('4.00')),
#  ('barra do rio azul', Decimal('4.00')),
#  ('marechal deodoro', Decimal('4.00')),
#  ('cerro grande', Decimal('4.00')),
#  ('senador la rocque', Decimal('4.00')),
#  ('francisco santos', Decimal('4.00')),
#  ('jamaica', Decimal('4.00')),
#  ('frei rogerio', Decimal('4.00')),
#  ('romelandia', Decimal('4.00')),
#  ('bela vista do maranhao', Decimal('4.00')),
#  ('herculandia', Decimal('4.00')),
#  ('coqueiros do sul', Decimal('4.00')),
#  ('morro redondo', Decimal('4.00')),
#  ('pureza', Decimal('4.00')),
#  ('cabaceiras do paraguacu', Decimal('4.00')),
#  ('monte gordo', Decimal('4.00')),
#  ('sertao santana', Decimal('4.00')),
#  ('queixada', Decimal('4.00')),
#  ('pinto bandeira', Decimal('4.00')),
#  ('itaicaba', Decimal('4.00')),
#  ('fragosos', Decimal('4.00')),
#  ('atalanta', Decimal('4.00')),
#  ('guiricema', Decimal('4.00')),
#  ('almirante tamandare do sul', Decimal('4.00')),
#  ('conceicao do almeida', Decimal('4.00')),
#  ('bom jesus do amparo', Decimal('4.00')),
#  ('joaima', Decimal('4.00')),
#  ('santo amaro das brotas', Decimal('4.00')),
#  ('lindolfo collor', Decimal('4.00')),
#  ('sideropolis', Decimal('4.00')),
#  ('sao nicolau', Decimal('4.00')),
#  ('irape', Decimal('4.00')),
#  ('sanga puita', Decimal('4.00')),
#  ('acajutiba', Decimal('4.00')),
#  ('estevao de araujo', Decimal('4.00')),
#  ('pedranopolis', Decimal('4.00')),
#  ('aratiba', Decimal('4.00')),
#  ('sarutaia', Decimal('4.00')),
#  ('sao joao de petropolis', Decimal('4.00')),
#  ('eugenio de castro', Decimal('4.00')),
#  ('chorozinho', Decimal('4.00')),
#  ('sao bento abade', Decimal('4.00')),
#  ('salinas da margarida', Decimal('4.00')),
#  ('missao velha', Decimal('4.00')),
#  ('matoes', Decimal('4.00')),
#  ('maquine', Decimal('4.00')),
#  ('croata', Decimal('4.00')),
#  ('maribondo', Decimal('4.00')),
#  ('moema', Decimal('4.00')),
#  ('itagimirim', Decimal('4.00')),
#  ('lagoa dos tres cantos', Decimal('4.00')),
#  ('massape', Decimal('4.00')),
#  ('bom jesus do sul', Decimal('4.00')),
#  ('constantina', Decimal('4.00')),
#  ('vargeao', Decimal('4.00')),
#  ('paranapoema', Decimal('4.00')),
#  ('salobro', Decimal('4.00')),
#  ('cupira', Decimal('4.00')),
#  ('cruzeiro do iguacu', Decimal('4.00')),
#  ('patis', Decimal('4.00')),
#  ('almino afonso', Decimal('4.00')),
#  ('carnaubal', Decimal('4.00')),
#  ('cabeceiras', Decimal('4.00')),
#  ('caldeirao grande do piaui', Decimal('4.00')),
#  ('paripueira', Decimal('4.00')),
#  ('buriti do tocantins', Decimal('4.00')),
#  ('paula candido', Decimal('4.00')),
#  ('santa maria do herval', Decimal('4.00')),
#  ('barra longa', Decimal('4.00')),
#  ('bugre', Decimal('4.00')),
#  ('nova santa barbara', Decimal('4.00')),
#  ('jaguaribara', Decimal('4.00')),
#  ('sede alvorada', Decimal('4.00')),
#  ('jussiape', Decimal('4.00')),
#  ('nova guarita', Decimal('4.00')),
#  ('bela vista de minas', Decimal('4.00')),
#  ('barreira', Decimal('4.00')),
#  ('nova timboteua', Decimal('4.00')),
#  ('vicentina', Decimal('4.00')),
#  ('varzedo', Decimal('4.00')),
#  ('florida', Decimal('4.00')),
#  ('cezarina', Decimal('4.00')),
#  ('reserva do iguacu', Decimal('4.00')),
#  ("conquista d'oeste", Decimal('4.00')),
#  ('sete de setembro', Decimal('4.00')),
#  ('palhano', Decimal('4.00')),
#  ('perobal', Decimal('4.00')),
#  ('sape', Decimal('4.00')),
#  ('montanhas', Decimal('4.00')),
#  ('fagundes', Decimal('4.00')),
#  ('nova araca', Decimal('4.00')),
#  ('pitimbu', Decimal('4.00')),
#  ('conrado', Decimal('4.00')),
#  ('conceicao do caninde', Decimal('4.00')),
#  ('sao sebastiao do paraiba', Decimal('4.00')),
#  ('feliz deserto', Decimal('4.00')),
#  ('aracatu', Decimal('4.00')),
#  ('lamarao', Decimal('4.00')),
#  ('sao jorge do oeste', Decimal('4.00')),
#  ('aiuaba', Decimal('4.00')),
#  ('pranchita', Decimal('4.00')),
#  ('brejo bonito', Decimal('4.00')),
#  ('termas de ibira', Decimal('4.00')),
#  ('goncalves dias', Decimal('4.00')),
#  ('anhembi', Decimal('4.00')),
#  ('cabixi', Decimal('4.00')),
#  ('goiandira', Decimal('4.00')),
#  ('areial', Decimal('4.00')),
#  ('sabaudia', Decimal('4.00')),
#  ('cajari', Decimal('4.00')),
#  ('coite do noia', Decimal('4.00')),
#  ("santa clara d'oeste", Decimal('4.00')),
#  ('agrestina', Decimal('4.00')),
#  ('vespasiano correa', Decimal('4.00')),
#  ('silvano', Decimal('4.00')),
#  ('unistalda', Decimal('4.00')),
#  ('mocajuba', Decimal('4.00')),
#  ('alvorada do gurgueia', Decimal('4.00')),
#  ('sao bentinho', Decimal('4.00')),
#  ('senador jose porfirio', Decimal('4.00')),
#  ('cotipora', Decimal('4.00')),
#  ('presidente castello branco', Decimal('4.00')),
#  ('pavao', Decimal('4.00')),
#  ('alto piquiri', Decimal('4.00')),
#  ('sao jose do xingu', Decimal('4.00')),
#  ('santana do ipanema', Decimal('4.00')),
#  ('vila bela da santissima trindade', Decimal('4.00')),
#  ('sao mamede', Decimal('4.00')),
#  ('sambaiba', Decimal('4.00')),
#  ('japaratuba', Decimal('4.00')),
#  ('tuiuti', Decimal('4.00')),
#  ('tibau do sul', Decimal('4.00')),
#  ('guariba', Decimal('4.00')),
#  ('tocos', Decimal('4.00')),
#  ('sao jose da tapera', Decimal('4.00')),
#  ('prata', Decimal('4.00')),
#  ('urucuca', Decimal('4.00')),
#  ('campos borges', Decimal('4.00')),
#  ('sao francisco de assis', Decimal('4.00')),
#  ('tabatinga', Decimal('4.00')),
#  ('boa esperanca do sul', Decimal('4.00')),
#  ('xique-xique', Decimal('4.00')),
#  ('sao borja', Decimal('4.00')),
#  ('ananas', Decimal('4.00')),
#  ('panorama', Decimal('4.00')),
#  ('rio formoso', Decimal('4.00')),
#  ('novo gama', Decimal('4.00')),
#  ('palmeira dos indios', Decimal('4.00')),
#  ('candiota', Decimal('4.00')),
#  ('conceicao dos ouros', Decimal('4.00')),
#  ('dumont', Decimal('4.00')),
#  ('cajueiro', Decimal('4.00')),
#  ('coronel joao sa', Decimal('4.00')),
#  ('campos de julio', Decimal('4.00')),
#  ('itacare', Decimal('4.00')),
#  ('trajano de moraes', Decimal('4.00')),
#  ('sao jose da lapa', Decimal('4.00')),
#  ('vargem grande', Decimal('4.00')),
#  ('agua fria de goias', Decimal('4.00')),
#  ('chavantes', Decimal('4.00')),
#  ('guaratinga', Decimal('4.00')),
#  ('pedra bela', Decimal('4.00')),
#  ('farroupilha', Decimal('4.00')),
#  ('rio negro', Decimal('4.00')),
#  ('pitanga', Decimal('4.00')),
#  ('pedro velho', Decimal('4.00')),
#  ('poco verde', Decimal('4.00')),
#  ('paraopeba', Decimal('4.00')),
#  ('rio brilhante', Decimal('4.00')),
#  ('tres pontas', Decimal('4.00')),
#  ('piracuruca', Decimal('4.00')),
#  ('desembargador otoni', Decimal('4.00')),
#  ('lauro muller', Decimal('4.00')),
#  ('lagoinha', Decimal('4.00')),
#  ('eugenopolis', Decimal('4.00')),
#  ('limoeiro', Decimal('4.00')),
#  ('bom jesus', Decimal('4.00')),
#  ('porto franco', Decimal('4.00')),
#  ('tombos', Decimal('4.00')),
#  ('ipiranga do norte', Decimal('4.00')),
#  ('santa fe do sul', Decimal('4.00')),
#  ('faxinal', Decimal('4.00')),
#  ('cidreira', Decimal('4.00')),
#  ('guaiuba', Decimal('4.00')),
#  ('itau de minas', Decimal('4.00')),
#  ('jussara', Decimal('4.00')),
#  ('sandolandia', Decimal('4.00')),
#  ('bonfim', Decimal('4.00')),
#  ('umuarama', Decimal('4.00')),
#  ('urutai', Decimal('4.00')),
#  ('fernao', Decimal('4.00')),
#  ('barbalha', Decimal('4.00')),
#  ('porto esperidiao', Decimal('4.00')),
#  ('matipo', Decimal('4.00')),
#  ('ibatiba', Decimal('4.00')),
#  ('saudade do iguacu', Decimal('4.00')),
#  ('sao joao da urtiga', Decimal('4.00')),
#  ('chacara', Decimal('4.00')),
#  ('cruzeiro do sul', Decimal('4.00')),
#  ('sao jose da coroa grande', Decimal('4.00')),
#  ('coelho neto', Decimal('4.00')),
#  ('nova venecia', Decimal('4.00')),
#  ('silvianopolis', Decimal('4.00')),
#  ('tijucas', Decimal('4.00')),
#  ('entre rios', Decimal('4.00')),
#  ('sao jose de uba', Decimal('4.00')),
#  ('sao vendelino', Decimal('4.00')),
#  ('glaura', Decimal('4.00')),
#  ('bituruna', Decimal('4.00')),
#  ('bom jesus do querendo', Decimal('4.00')),
#  ('brejo da madre de deus', Decimal('4.00')),
#  ('itanhem', Decimal('4.00')),
#  ('cachoeira de minas', Decimal('4.00')),
#  ('cajuru', Decimal('4.00')),
#  ('forquilha', Decimal('4.00')),
#  ('matozinhos', Decimal('4.00')),
#  ('juscimeira', Decimal('4.00')),
#  ('cedro', Decimal('4.00')),
#  ('itapecerica', Decimal('4.00')),
#  ('itaberaba', Decimal('4.00')),
#  ('campo belo', Decimal('4.00')),
#  ('afonso claudio', Decimal('4.00')),
#  ('aruana', Decimal('4.00')),
#  ('salgueiro', Decimal('4.00')),
#  ('colniza', Decimal('4.00')),
#  ('prado', Decimal('4.00')),
#  ('morungaba', Decimal('4.00')),
#  ('tarabai', Decimal('4.00')),
#  ('encruzilhada do sul', Decimal('4.00')),
#  ('ivora', Decimal('4.00')),
#  ('buriti dos lopes', Decimal('4.00')),
#  ('ibiraci', Decimal('4.00')),
#  ('taperuaba', Decimal('4.00')),
#  ('espigao do oeste', Decimal('4.00')),
#  ('ribeira', Decimal('4.00')),
#  ('monte santo de minas', Decimal('4.00')),
#  ('biguacu', Decimal('4.00')),
#  ('peabiru', Decimal('4.00')),
#  ('regeneracao', Decimal('4.00')),
#  ('formosa da serra negra', Decimal('4.00')),
#  ('ivoti', Decimal('4.00')),
#  ('nossa senhora do remedio', Decimal('4.00')),
#  ('conquista', Decimal('4.00')),
#  ('cedro de sao joao', Decimal('4.00')),
#  ('pontal do parana', Decimal('4.00')),
#  ('turvo', Decimal('4.00')),
#  ('vila muriqui', Decimal('4.00')),
#  ('palma', Decimal('4.00')),
#  ('alfredo chaves', Decimal('4.00')),
#  ('fraiburgo', Decimal('4.00')),
#  ('campos altos', Decimal('4.00')),
#  ('passa tres', Decimal('4.00')),
#  ('charqueada', Decimal('4.00')),
#  ('miguelopolis', Decimal('4.00')),
#  ('poxoreu', Decimal('4.00')),
#  ('guaruja do sul', Decimal('4.00')),
#  ('santa vitoria', Decimal('4.00')),
#  ('paiva', Decimal('4.00')),
#  ('antonio carlos', Decimal('4.00')),
#  ('inga', Decimal('4.00')),
#  ('japi', Decimal('4.00')),
#  ('sao francisco do guapore', Decimal('4.00')),
#  ('sao miguel do aleixo', Decimal('4.00')),
#  ('cipo-guacu', Decimal('4.00')),
#  ('maioba', Decimal('4.00')),
#  ('terra boa', Decimal('4.00')),
#  ('xaxim', Decimal('4.00')),
#  ('barauna', Decimal('4.00')),
#  ('banabuiu', Decimal('4.00')),
#  ('cortes', Decimal('4.00')),
#  ('rainha do mar', Decimal('4.00')),
#  ('quintana', Decimal('4.00')),
#  ('marituba', Decimal('4.00')),
#  ('corbelia', Decimal('4.00')),
#  ('soledade', Decimal('4.00')),
#  ('formoso do araguaia', Decimal('4.00')),
#  ('igaratinga', Decimal('4.00')),
#  ('tangara da serra', Decimal('4.00')),
#  ('guaranta', Decimal('4.00')),
#  ('lagoa dos gatos', Decimal('4.00')),
#  ('crisolita', Decimal('4.00')),
#  ('monte castelo', Decimal('4.00')),
#  ('arraias', Decimal('4.00')),
#  ('felipe guerra', Decimal('4.00')),
#  ('joanopolis', Decimal('4.00')),
#  ('igarata', Decimal('4.00')),
#  ('ecoporanga', Decimal('4.00')),
#  ('lavras da mangabeira', Decimal('4.00')),
#  ('tres marias', Decimal('4.00')),
#  ('redentora', Decimal('4.00')),
#  ('quatigua', Decimal('4.00')),
#  ('liberdade', Decimal('4.00')),
#  ('araruna', Decimal('4.00')),
#  ('porto uniao', Decimal('4.00')),
#  ('itaberai', Decimal('4.00')),
#  ('estacao', Decimal('4.00')),
#  ('sao joao do manhuacu', Decimal('4.00')),
#  ('valenca do piaui', Decimal('4.00')),
#  ('ipiranga', Decimal('4.00')),
#  ('varre-sai', Decimal('4.00')),
#  ('aripuana', Decimal('4.00')),
#  ('gameleiras', Decimal('4.00')),
#  ('anaurilandia', Decimal('4.00')),
#  ('apuiares', Decimal('4.00')),
#  ('ilha comprida', Decimal('4.00')),
#  ('engenheiro coelho', Decimal('4.00')),
#  ('caravelas', Decimal('4.00')),
#  ('nova cruz', Decimal('4.00')),
#  ('pacaja', Decimal('4.00')),
#  ('nhandeara', Decimal('4.00')),
#  ('sarandi', Decimal('4.00')),
#  ('muritiba', Decimal('4.00')),
#  ('cedral', Decimal('4.00')),
#  ('cuite', Decimal('4.00')),
#  ('uaua', Decimal('4.00')),
#  ('godoy moreira', Decimal('4.00')),
#  ('monnerat', Decimal('4.00')),
#  ('santa rita do araguaia', Decimal('4.00')),
#  ('iturama', Decimal('4.00')),
#  ('santa terezinha', Decimal('4.00')),
#  ('itapiuna', Decimal('4.00')),
#  ('santa rosa de lima', Decimal('4.00')),
#  ('palmares', Decimal('4.00')),
#  ('queluz', Decimal('4.00')),
#  ('urucurituba', Decimal('4.00')),
#  ('cordeiros', Decimal('4.00')),
#  ('bom principio', Decimal('4.00')),
#  ('tiangua', Decimal('4.00')),
#  ('aurea', Decimal('4.00')),
#  ('lagoa vermelha', Decimal('4.00')),
#  ('ribeirao', Decimal('4.00')),
#  ('ibirataia', Decimal('4.00')),
#  ('lucelia', Decimal('4.00')),
#  ('victor graeff', Decimal('4.00')),
#  ('firminopolis', Decimal('4.00')),
#  ('canapi', Decimal('4.00')),
#  ('chapada do norte', Decimal('4.00')),
#  ('cambuci', Decimal('4.00')),
#  ('itagiba', Decimal('4.00')),
#  ('una', Decimal('4.00')),
#  ('urussanga', Decimal('4.00')),
#  ('chorrocho', Decimal('4.00')),
#  ('anicuns', Decimal('4.00')),
#  ('ze doca', Decimal('4.00')),
#  ('ibiam', Decimal('4.00')),
#  ('sao simao', Decimal('4.00')),
#  ('moncoes', Decimal('4.00')),
#  ('areia branca', Decimal('4.00')),
#  ('nova laranjeiras', Decimal('4.00')),
#  ('santa cruz das palmeiras', Decimal('4.00')),
#  ('iraucuba', Decimal('4.00')),
#  ('casca', Decimal('4.00')),
#  ('vargem alta', Decimal('4.00')),
#  ('camutanga', Decimal('4.00')),
#  ('floriano', Decimal('4.00')),
#  ('centenario do sul', Decimal('4.00')),
#  ('florai', Decimal('4.00')),
#  ('mossamedes', Decimal('4.00')),
#  ('bela cruz', Decimal('4.00')),
#  ('sao jose de ribamar', Decimal('4.00')),
#  ('ouricuri', Decimal('4.00')),
#  ('tucano', Decimal('4.00')),
#  ('eldorado do sul', Decimal('4.00')),
#  ('parobe', Decimal('4.00')),
#  ('caraubas', Decimal('4.00')),
#  ('santo antonio do rio abaixo', Decimal('4.00')),
#  ('lajedo', Decimal('4.00')),
#  ('sao joao batista', Decimal('4.00')),
#  ('araguaia', Decimal('4.00')),
#  ('nossa senhora de lourdes', Decimal('4.00')),
#  ('trombudo central', Decimal('4.00')),
#  ('concordia do para', Decimal('4.00')),
#  ('manoel viana', Decimal('4.00')),
#  ('conceicao do araguaia', Decimal('4.00')),
#  ('cardoso', Decimal('4.00')),
#  ('caibi', Decimal('4.00')),
#  ('alegria', Decimal('4.00')),
#  ('sao sebastiao da serra', Decimal('4.00')),
#  ('ampere', Decimal('4.00')),
#  ('barra de sao francisco', Decimal('4.00')),
#  ('lunardelli', Decimal('4.00')),
#  ('barra', Decimal('4.00')),
#  ('oliveira', Decimal('4.00')),
#  ('bom jesus do tocantins', Decimal('4.00')),
#  ('uniao de minas', Decimal('4.00')),
#  ('paraguacu paulista', Decimal('4.00')),
#  ('cha grande', Decimal('4.00')),
#  ('promissao', Decimal('4.00')),
#  ('materlandia', Decimal('4.00')),
#  ('utinga', Decimal('4.00')),
#  ('virginia', Decimal('4.00')),
#  ('espera feliz', Decimal('4.00')),
#  ('bom sucesso', Decimal('4.00')),
#  ('general carneiro', Decimal('4.00')),
#  ('mirandiba', Decimal('4.00')),
#  ('terra rica', Decimal('4.00')),
#  ('nova santa rosa', Decimal('4.00')),
#  ('ibicarai', Decimal('4.00')),
#  ('humaita', Decimal('4.00')),
#  ('vargem grande do sul', Decimal('4.00')),
#  ('corumba de goias', Decimal('4.00')),
#  ('aquidauana', Decimal('4.00')),
#  ('sao martinho', Decimal('4.00')),
#  ('pantano grande', Decimal('4.00')),
#  ('porangaba', Decimal('4.00')),
#  ('tocantins', Decimal('4.00')),
#  ('diamantino', Decimal('4.00')),
#  ('rio manso', Decimal('4.00')),
#  ('taua', Decimal('4.00')),
#  ('bocaiuva', Decimal('4.00')),
#  ('brazopolis', Decimal('4.00')),
#  ('santa maria madalena', Decimal('4.00')),
#  ('goianapolis', Decimal('4.00')),
#  ('estrela', Decimal('4.00')),
#  ('novo mundo', Decimal('4.00')),
#  ("perola d'oeste", Decimal('4.00')),
#  ('gameleira', Decimal('4.00')),
#  ('rio preto', Decimal('4.00')),
#  ('coruripe', Decimal('4.00')),
#  ('varzea alegre', Decimal('4.00')),
#  ('jatauba', Decimal('4.00')),
#  ('engenheiro beltrao', Decimal('4.00')),
#  ('altos', Decimal('4.00')),
#  ('livramento', Decimal('4.00')),
#  ('canavieiras', Decimal('4.00')),
#  ('aparecida', Decimal('4.00')),
#  ('paripiranga', Decimal('4.00')),
#  ('sao pedro do sul', Decimal('4.00')),
#  ('coimbra', Decimal('4.00')),
#  ('marcos parente', Decimal('4.00')),
#  ('carvalhopolis', Decimal('4.00')),
#  ('peixoto de azevedo', Decimal('4.00')),
#  ('cabreuva', Decimal('4.00')),
#  ('ouro verde', Decimal('4.00')),
#  ('tapiratiba', Decimal('4.00')),
#  ('porteirinha', Decimal('4.00')),
#  ('guarani', Decimal('4.00')),
#  ('sananduva', Decimal('4.00')),
#  ('denise', Decimal('4.00')),
#  ('riolandia', Decimal('4.00')),
#  ('primeiro de maio', Decimal('4.00')),
#  ('resplendor', Decimal('4.00')),
#  ('conceicao do para', Decimal('4.00')),
#  ('lupercio', Decimal('4.00')),
#  ('sirinhaem', Decimal('4.00')),
#  ('novo oriente do piaui', Decimal('4.00')),
#  ('sao goncalo do sapucai', Decimal('4.00')),
#  ('descoberto', Decimal('4.00')),
#  ('candeias', Decimal('4.00')),
#  ('arrozal', Decimal('4.00')),
#  ('pentecoste', Decimal('4.00')),
#  ('capinzal do norte', Decimal('4.00')),
#  ('crateus', Decimal('4.00')),
#  ('propria', Decimal('4.00')),
#  ('adolfo', Decimal('4.00')),
#  ('tres coroas', Decimal('4.00')),
#  ('oscar bressane', Decimal('4.00')),
#  ('cerro azul', Decimal('4.00')),
#  ('aiuruoca', Decimal('4.00')),
#  ('pindorama do tocantins', Decimal('4.00')),
#  ('faxinalzinho', Decimal('4.00')),
#  ('indiaroba', Decimal('4.00')),
#  ('araguaina', Decimal('4.00')),
#  ('maria da fe', Decimal('4.00')),
#  ('schroeder', Decimal('4.00')),
#  ('itiquira', Decimal('4.00')),
#  ('mucuri', Decimal('4.00')),
#  ('abre campo', Decimal('4.00')),
#  ('parai', Decimal('4.00')),
#  ('lagoa da confusao', Decimal('4.00')),
#  ('sabino', Decimal('4.00')),
#  ('porto de pedras', Decimal('4.00')),
#  ('altonia', Decimal('4.00')),
#  ('tabira', Decimal('4.00')),
#  ('altinopolis', Decimal('4.00')),
#  ('ribeirao branco', Decimal('4.00')),
#  ('campestre', Decimal('4.00')),
#  ('coribe', Decimal('4.00')),
#  ('tabapora', Decimal('4.00')),
#  ('sao joao das missoes', Decimal('4.00')),
#  ('pacoti', Decimal('4.00')),
#  ('mojui dos campos', Decimal('4.00')),
#  ('altinho', Decimal('4.00')),
#  ('jaguaruana', Decimal('4.00')),
#  ('cameta', Decimal('4.00')),
#  ('quevedos', Decimal('4.00')),
#  ('araguapaz', Decimal('4.00')),
#  ('jequitinhonha', Decimal('4.00')),
#  ('bombinhas', Decimal('4.00')),
#  ('ibema', Decimal('4.00')),
#  ('astorga', Decimal('4.00')),
#  ('pereira barreto', Decimal('4.00')),
#  ('santa fe de goias', Decimal('4.00')),
#  ('marilandia', Decimal('4.00')),
#  ('morada nova', Decimal('4.00')),
#  ('marilandia do sul', Decimal('4.00')),
#  ('mostardas', Decimal('4.00')),
#  ('gastao vidigal', Decimal('4.00')),
#  ("sao joao d'alianca", Decimal('4.00')),
#  ('santa cecilia do pavao', Decimal('4.00')),
#  ('santo antonio de posse', Decimal('4.00')),
#  ('fortaleza dos valos', Decimal('4.00')),
#  ('jaua', Decimal('4.00')),
#  ('berilo', Decimal('4.00')),
#  ('gandu', Decimal('4.00')),
#  ('tavares', Decimal('4.00')),
#  ('senador modestino goncalves', Decimal('4.00')),
#  ('rubim', Decimal('4.00')),
#  ('acailandia', Decimal('4.00')),
#  ('arcoverde', Decimal('4.00')),
#  ('dom cavati', Decimal('4.00')),
#  ('conceicao do castelo', Decimal('4.00')),
#  ('cocal', Decimal('4.00')),
#  ("mirassol d'oeste", Decimal('4.00')),
#  ('martins soares', Decimal('4.00')),
#  ('campos belos', Decimal('4.00')),
#  ('joviania', Decimal('4.00')),
#  ('aimores', Decimal('4.00')),
#  ('nazare', Decimal('4.00')),
#  ('casa branca', Decimal('4.00')),
#  ('venturosa', Decimal('4.00')),
#  ('barra do mendes', Decimal('4.00')),
#  ('jacobina', Decimal('4.00')),
#  ('soledade de minas', Decimal('4.00')),
#  ('joaquim nabuco', Decimal('4.00')),
#  ('santa izabel do oeste', Decimal('4.00')),
#  ('pedro ii', Decimal('4.00')),
#  ('sao domingos do norte', Decimal('4.00')),
#  ('montividiu do norte', Decimal('4.00')),
#  ('jaguaribe', Decimal('4.00')),
#  ('oros', Decimal('4.00')),
#  ('rio branco do sul', Decimal('4.00')),
#  ('aracuai', Decimal('4.00')),
#  ('perdigao', Decimal('4.00')),
#  ('lagarto', Decimal('4.00')),
#  ('carazinho', Decimal('4.00')),
#  ('santo antonio do sudoeste', Decimal('4.00')),
#  ('sapezal', Decimal('4.00')),
#  ('indianopolis', Decimal('4.00')),
#  ('santa barbara do para', Decimal('4.00')),
#  ('bonito', Decimal('4.00')),
#  ('major vieira', Decimal('4.00')),
#  ('ibarama', Decimal('4.00')),
#  ('esperantinopolis', Decimal('4.00')),
#  ('serra do salitre', Decimal('4.00')),
#  ('nuporanga', Decimal('4.00')),
#  ('jacarezinho', Decimal('4.00')),
#  ('missal', Decimal('4.00')),
#  ('mineiros do tiete', Decimal('4.00')),
#  ('ivaipora', Decimal('4.00')),
#  ('arace', Decimal('4.00')),
#  ('domingos martins', Decimal('4.00')),
#  ('simao dias', Decimal('4.00')),
#  ('angatuba', Decimal('4.00')),
#  ('rio dos cedros', Decimal('4.00')),
#  ('sao goncalo do abaete', Decimal('4.00')),
#  ('dores de campos', Decimal('4.00')),
#  ('mimoso do sul', Decimal('4.00')),
#  ('manhumirim', Decimal('4.00')),
#  ('esperanca', Decimal('4.00')),
#  ('taquarivai', Decimal('4.00')),
#  ('chopinzinho', Decimal('4.00')),
#  ('nova olimpia', Decimal('4.00')),
#  ('urai', Decimal('4.00')),
#  ('santa rita', Decimal('4.00')),
#  ('pedrinhas paulista', Decimal('4.00')),
#  ('novo repartimento', Decimal('4.00')),
#  ('pesqueira', Decimal('4.00')),
#  ('guararema', Decimal('4.00')),
#  ('carapebus', Decimal('4.00')),
#  ('chui', Decimal('4.00')),
#  ('nova aurora', Decimal('4.00')),
#  ('alpestre', Decimal('4.00')),
#  ('olindina', Decimal('4.00')),
#  ('monte formoso', Decimal('4.00')),
#  ('acaiaca', Decimal('4.00')),
#  ('caxambu', Decimal('4.00')),
#  ('sao miguel arcanjo', Decimal('4.00')),
#  ('cristiano otoni', Decimal('4.00')),
#  ('sao jorge do patrocinio', Decimal('4.00')),
#  ('caetite', Decimal('4.00')),
#  ('nova olinda do maranhao', Decimal('4.00')),
#  ('oeiras', Decimal('4.00')),
#  ('igaracu do tiete', Decimal('4.00')),
#  ('ervalia', Decimal('4.00')),
#  ('sao manuel', Decimal('4.00')),
#  ("arraial d'ajuda", Decimal('4.00')),
#  ('mar vermelho', Decimal('4.00')),
#  ('ceu azul', Decimal('4.00')),
#  ('valentim gentil', Decimal('4.00')),
#  ('apiaca', Decimal('4.00')),
#  ('novo oriente de minas', Decimal('4.00')),
#  ('ribeira do amparo', Decimal('4.00')),
#  ('werneck', Decimal('4.00')),
#  ('ielmo marinho', Decimal('4.00')),
#  ('corumbatai do sul', Decimal('4.00')),
#  ('lamim', Decimal('4.00')),
#  ('tailandia', Decimal('4.00')),
#  ('macuco de minas', Decimal('4.00')),
#  ('maranguape', Decimal('4.00')),
#  ('bom jardim', Decimal('4.00')),
#  ('aragarcas', Decimal('4.00')),
#  ('conchas', Decimal('4.00')),
#  ('motuca', Decimal('4.00')),
#  ('capivari de baixo', Decimal('4.00')),
#  ('bom retiro do sul', Decimal('4.00')),
#  ('coronel macedo', Decimal('4.00')),
#  ('alto araguaia', Decimal('4.00')),
#  ('grao mogol', Decimal('4.00')),
#  ('ipumirim', Decimal('4.00')),
#  ('recreio', Decimal('4.00')),
#  ('dias d avila', Decimal('4.00')),
#  ('ceres', Decimal('4.00')),
#  ('conceicao do jacuipe', Decimal('4.00')),
#  ('sao jose da boa vista', Decimal('4.00')),
#  ('divinolandia', Decimal('4.00')),
#  ('protasio alves', Decimal('4.00')),
#  ('novo cruzeiro', Decimal('4.00')),
#  ('caracol', Decimal('4.00')),
#  ('planalto', Decimal('4.00')),
#  ('imbau', Decimal('4.00')),
#  ('santo amaro de campos', Decimal('4.00')),
#  ('cururupu', Decimal('4.00')),
#  ('sapucai-mirim', Decimal('4.00')),
#  ('florestal', Decimal('4.00')),
#  ('campo azul', Decimal('4.00')),
#  ('ouro preto do oeste', Decimal('4.00')),
#  ('sao domingos', Decimal('4.00')),
#  ('pratapolis', Decimal('4.00')),
#  ('brejoes', Decimal('4.00')),
#  ('guaraci', Decimal('4.00')),
#  ('iconha', Decimal('4.00')),
#  ('jeremoabo', Decimal('4.00')),
#  ('ipojuca', Decimal('4.00')),
#  ('sume', Decimal('4.00')),
#  ('nova europa', Decimal('4.00')),
#  ('bacuri', Decimal('4.00')),
#  ('carlopolis', Decimal('4.00')),
#  ('lagoa nova', Decimal('4.00')),
#  ('alto rio novo', Decimal('4.00')),
#  ('piquete', Decimal('4.00')),
#  ('augusto correa', Decimal('4.00')),
#  ('buenos aires', Decimal('4.00')),
#  ('itamaraju', Decimal('4.00')),
#  ('jequitiba', Decimal('4.00')),
#  ('penedo', Decimal('4.00')),
#  ('tapejara', Decimal('4.00')),
#  ('luminarias', Decimal('4.00')),
#  ('baguari', Decimal('4.00')),
#  ('carneirinho', Decimal('4.00')),
#  ('alto parnaiba', Decimal('4.00')),
#  ('maragogi', Decimal('4.00')),
#  ('picarras', Decimal('4.00')),
#  ('reserva do cabacal', Decimal('4.00')),
#  ('uniao', Decimal('4.00')),
#  ('pedra branca', Decimal('4.00')),
#  ('restinga seca', Decimal('4.00')),
#  ('itapicuru', Decimal('4.00')),
#  ('antonio cardoso', Decimal('4.00')),
#  ('quilombo', Decimal('4.00')),
#  ('guaraciaba do norte', Decimal('4.00')),
#  ('curaca', Decimal('4.00')),
#  ('natercia', Decimal('4.00')),
#  ('irineopolis', Decimal('4.00')),
#  ('urupa', Decimal('4.00')),
#  ('saboeiro', Decimal('4.00')),
#  ('rio pardo', Decimal('4.00')),
#  ('icarai de minas', Decimal('4.00')),
#  ('duere', Decimal('4.00')),
#  ('ibaiti', Decimal('4.00')),
#  ('manduri', Decimal('4.00')),
#  ('sao goncalo do rio preto', Decimal('4.00')),
#  ('barrolandia', Decimal('4.00')),
#  ('vigia', Decimal('4.00')),
#  ('dionisio', Decimal('4.00')),
#  ('arvorezinha', Decimal('4.00')),
#  ('novo planalto', Decimal('4.00')),
#  ('santa tereza do oeste', Decimal('4.00')),
#  ('vanini', Decimal('4.00')),
#  ('nova erechim', Decimal('4.00')),
#  ('antonio pereira', Decimal('4.00')),
#  ('ibitiuva', Decimal('4.00')),
#  ('inhauma', Decimal('4.00')),
#  ('lourdes', Decimal('4.00')),
#  ('tomazina', Decimal('4.00')),
#  ('roncador', Decimal('4.00')),
#  ('ibimirim', Decimal('4.00')),
#  ('santana da boa vista', Decimal('4.00')),
#  ('aguas de sao pedro', Decimal('4.00')),
#  ('paco do lumiar', Decimal('4.00')),
#  ('paraiso das aguas', Decimal('4.00')),
#  ('mariopolis', Decimal('4.00')),
#  ('cocal do sul', Decimal('4.00')),
#  ('urbano santos', Decimal('4.00')),
#  ('xavantina', Decimal('4.00')),
#  ('presidente medici', Decimal('4.00')),
#  ('ametista do sul', Decimal('4.00')),
#  ('jucurutu', Decimal('4.00')),
#  ('canudos', Decimal('4.00')),
#  ('anita garibaldi', Decimal('4.00')),
#  ('pirangi', Decimal('4.00')),
#  ('cachoeira', Decimal('4.00')),
#  ('varzea da palma', Decimal('4.00')),
#  ('granja', Decimal('4.00')),
#  ('salto do itarare', Decimal('4.00')),
#  ('varzea do poco', Decimal('4.00')),
#  ('sao bonifacio', Decimal('4.00')),
#  ('itabirinha', Decimal('4.00')),
#  ('braunas', Decimal('4.00')),
#  ('sao jose do belmonte', Decimal('4.00')),
#  ('sao jose do barreiro', Decimal('4.00')),
#  ('castelandia', Decimal('4.00')),
#  ('itabatan', Decimal('4.00')),
#  ('esperantina', Decimal('4.00')),
#  ('cardoso moreira', Decimal('4.00')),
#  ('itambe', Decimal('4.00')),
#  ('inubia paulista', Decimal('4.00')),
#  ('pacotuba', Decimal('4.00')),
#  ('iaciara', Decimal('4.00')),
#  ('dona emma', Decimal('4.00')),
#  ('santa cruz de salinas', Decimal('4.00')),
#  ('baturite', Decimal('4.00')),
#  ('serrana', Decimal('4.00')),
#  ('cruz machado', Decimal('4.00')),
#  ('sulina', Decimal('4.00')),
#  ('ipixuna do para', Decimal('4.00')),
#  ('governador portela', Decimal('4.00')),
#  ('sao bras do suacui', Decimal('4.00')),
#  ('itapura', Decimal('4.00')),
#  ('ventania', Decimal('4.00')),
#  ('formoso', Decimal('4.00')),
#  ('palotina', Decimal('4.00')),
#  ('mira estrela', Decimal('4.00')),
#  ('itapui', Decimal('4.00')),
#  ('maraba', Decimal('4.00')),
#  ('areiopolis', Decimal('4.00')),
#  ('cassia', Decimal('4.00')),
#  ('sao joao do paraiso', Decimal('4.00')),
#  ('presidente bernardes', Decimal('4.00')),
#  ('pilar', Decimal('4.00')),
#  ('macaiba', Decimal('4.00')),
#  ('canaa dos carajas', Decimal('4.00')),
#  ('cajati', Decimal('4.00')),
#  ('alcobaca', Decimal('4.00')),
#  ('paracuru', Decimal('4.00')),
#  ('jacupiranga', Decimal('4.00')),
#  ('turvelandia', Decimal('4.00')),
#  ('guarei', Decimal('4.00')),
#  ('simonesia', Decimal('4.00')),
#  ('cajuri', Decimal('4.00')),
#  ('ribeirao bonito', Decimal('4.00')),
#  ("machadinho d'oeste", Decimal('4.00')),
#  ('corinto', Decimal('4.00')),
#  ('pindare mirim', Decimal('4.00')),
#  ('cumaru', Decimal('4.00')),
#  ('chapada dos guimaraes', Decimal('4.00')),
#  ('jari', Decimal('4.00')),
#  ('santa quiteria', Decimal('4.00')),
#  ('dezesseis de novembro', Decimal('4.00')),
#  ('igaci', Decimal('4.00')),
#  ('lobato', Decimal('4.00')),
#  ('pio ix', Decimal('4.00')),
#  ('campo verde', Decimal('4.00')),
#  ('cananeia', Decimal('4.00')),
#  ('lucena', Decimal('4.00')),
#  ('catanduvas', Decimal('4.00')),
#  ('iguape', Decimal('4.00')),
#  ('santa salete', Decimal('4.00')),
#  ('sao bernardo', Decimal('4.00')),
#  ('maravilha', Decimal('4.00')),
#  ('silveira carvalho', Decimal('4.00')),
#  ('surubim', Decimal('4.00')),
#  ('itaperucu', Decimal('4.00')),
#  ('paicandu', Decimal('4.00')),
#  ('cantanhede', Decimal('4.00')),
#  ('floreal', Decimal('4.00')),
#  ('guape', Decimal('4.00')),
#  ('capim branco', Decimal('4.00')),
#  ('itirucu', Decimal('4.00')),
#  ('carmo de minas', Decimal('4.00')),
#  ('sao sebastiao da grama', Decimal('4.00')),
#  ('santa brigida', Decimal('4.00')),
#  ('serra dourada', Decimal('4.00')),
#  ('itatinga', Decimal('4.00')),
#  ('andarai', Decimal('4.00')),
#  ('goiana', Decimal('4.00')),
#  ('itauba', Decimal('4.00')),
#  ('itapitanga', Decimal('4.00')),
#  ('tracuateua', Decimal('4.00')),
#  ('mansidao', Decimal('4.00')),
#  ('fazenda vilanova', Decimal('4.00')),
#  ('sumidouro', Decimal('4.00')),
#  ('iacu', Decimal('4.00')),
#  ('orleans', Decimal('4.00')),
#  ('sericita', Decimal('4.00')),
#  ('caiana', Decimal('4.00')),
#  ('sao felipe', Decimal('4.00')),
#  ('ivate', Decimal('4.00')),
#  ('tangua', Decimal('4.00')),
#  ('estiva gerbi', Decimal('4.00')),
#  ('cocos', Decimal('4.00')),
#  ('humildes', Decimal('4.00')),
#  ('nova fatima', Decimal('4.00')),
#  ('nova russas', Decimal('4.00')),
#  ('luzilandia', Decimal('4.00')),
#  ('sao lourenco do oeste', Decimal('4.00')),
#  ('bocaiuva do sul', Decimal('4.00')),
#  ('abelardo luz', Decimal('4.00')),
#  ('camamu', Decimal('4.00')),
#  ('orindiuva', Decimal('4.00')),
#  ('morro da fumaca', Decimal('4.00')),
#  ('conceicao das alagoas', Decimal('4.00')),
#  ('missi', Decimal('4.00')),
#  ('alto rio doce', Decimal('4.00')),
#  ('castro alves', Decimal('4.00')),
#  ('presidente juscelino', Decimal('4.00')),
#  ('butia', Decimal('4.00')),
#  ('ourizona', Decimal('4.00')),
#  ('trindade do sul', Decimal('4.00')),
#  ('goias', Decimal('4.00')),
#  ('oeiras do para', Decimal('4.00')),
#  ('janduis', Decimal('4.00')),
#  ('barra do tarrachil', Decimal('4.00')),
#  ('carbonita', Decimal('4.00')),
#  ('santa barbara do sul', Decimal('4.00')),
#  ('santa cruz cabralia', Decimal('4.00')),
#  ('santa branca', Decimal('4.00')),
#  ('satiro dias', Decimal('4.00')),
#  ('palmitos', Decimal('4.00')),
#  ('barra de santo antonio', Decimal('4.00')),
#  ('jordania', Decimal('4.00')),
#  ('bras pires', Decimal('4.00')),
#  ('morretes', Decimal('4.00')),
#  ('sao miguel do iguacu', Decimal('4.00')),
#  ('itaja', Decimal('4.00')),
#  ('flor da serra do sul', Decimal('4.00')),
#  ('mozarlandia', Decimal('4.00')),
#  ('belo vale', Decimal('4.00')),
#  ('nazario', Decimal('4.00')),
#  ('rolim de moura', Decimal('4.00')),
#  ('bom conselho', Decimal('4.00')),
#  ('cachoeira do campo', Decimal('4.00')),
#  ('tucunduva', Decimal('4.00')),
#  ('carpina', Decimal('4.00')),
#  ('alvaro de carvalho', Decimal('4.00')),
#  ('medeiros neto', Decimal('4.00')),
#  ('brauna', Decimal('4.00')),
#  ('sao jose da laje', Decimal('4.00')),
#  ('rio largo', Decimal('4.00')),
#  ('serafina correa', Decimal('4.00')),
#  ('cedro do abaete', Decimal('4.00')),
#  ('sao mateus de minas', Decimal('4.00')),
#  ('piau', Decimal('4.00')),
#  ('centralina', Decimal('4.00')),
#  ('arroio trinta', Decimal('4.00')),
#  ('caarapo', Decimal('4.00')),
#  ...]

# %% [markdown]
# # Calculate the percentage of total revenue contributed by each product category.

# %%
query = """ select upper(products.product_category) category, 
round((sum(payments.payment_value)/(select sum(payment_value) from payments))*100,2) sales_percentage
from products join order_items
on products.product_id = order_items.product_id
join payments
on payments.order_id = order_items.order_id
group by category order by sales_percentage desc
"""

cur.execute(query)

data = cur.fetchall()

data
# Out:
# [('BED TABLE BATH', 42.79),
#  ('HEALTH BEAUTY', 41.41),
#  ('COMPUTER ACCESSORIES', 39.61),
#  ('FURNITURE DECORATION', 35.73),
#  ('WATCHES PRESENT', 35.71),
#  ('SPORT LEISURE', 34.78),
#  ('HOUSEWARES', 27.35),
#  ('AUTOMOTIVE', 21.3),
#  ('GARDEN TOOLS', 20.95),
#  ('COOL STUFF', 19.48),
#  ('FURNITURE OFFICE', 16.16),
#  ('TOYS', 15.47),
#  ('BABIES', 13.49),
#  ('PERFUMERY', 12.66),
#  ('TELEPHONY', 12.17),
#  ('STATIONARY STORE', 7.93),
#  ('PET SHOP', 7.78),
#  ('PCS', 6.97),
#  ('ELECTRONICS', 6.49),
#  (None, 6.32),
#  ('CONSTRUCTION TOOLS CONSTRUCTION', 6.03),
#  ('MUSICAL INSTRUMENTS', 5.82),
#  ('ELECTROSTILE', 5.64),
#  ('FASHION BAGS AND ACCESSORIES', 5.45),
#  ('FIXED TELEPHONY', 5.17),
#  ('GAMES CONSOLES', 4.88),
#  ('BAGS ACCESSORIES', 4.68),
#  ('CASA CONSTRUCAO', 3.41),
#  ('ROOM FURNITURE', 3.4),
#  ('ELECTRICES 2', 3.11),
#  ('AGRO INDUSTRIA E COMERCIO', 2.97),
#  ('HOME APPLIANCES', 2.39),
#  ('CLIMATIZATION', 2.28),
#  ('HOUSE COMFORT', 2.11),
#  ('FURNITURE KITCHEN SERVICE AREA DINNER AND GARDEN', 1.87),
#  ('CONSTRUCTION TOOLS ILLUMINATION', 1.82),
#  ('DRINKS', 1.78),
#  ('SIGNALIZATION AND SAFETY', 1.71),
#  ('CONSTRUCTION SECURITY TOOLS', 1.64),
#  ('GENERAL INTEREST BOOKS', 1.62),
#  ('AUDIO', 1.51),
#  ('INDUSTRY COMMERCE AND BUSINESS', 1.42),
#  ('HOUSE PASTALS OVEN AND CAFE', 1.28),
#  ('FOODS', 1.16),
#  ('MARKET PLACE', 1.13),
#  ('CONSTRUCTION TOOLS GARDEN', 1.06),
#  ('FASHION CALCADOS', 0.81),
#  ('FURNITURE', 0.79),
#  ('ART', 0.77),
#  ('DRINK FOODS', 0.68),
#  ('TECHNICAL BOOKS', 0.62),
#  ('CONSTRUCTION TOOLS TOOLS', 0.53),
#  ('CHRISTMAS ARTICLES', 0.47),
#  ("FASHION MEN'S CLOTHING", 0.43),
#  ('FASHION UNDERWEAR AND BEACH FASHION', 0.32),
#  ('IMAGE IMPORT TABLETS', 0.25),
#  ('CINE PHOTO', 0.24),
#  ('BLU RAY DVDS', 0.2),
#  ('SONG', 0.17),
#  ('IMPORTED BOOKS', 0.17),
#  ('PARTY ARTICLES', 0.15),
#  ('CITTE AND UPHACK FURNITURE', 0.15),
#  ("FASHION WOMEN'S CLOTHING", 0.13),
#  ('HYGIENE DIAPERS', 0.11),
#  ('KITCHEN PORTABLE AND FOOD COACH', 0.11),
#  ('FASHION SPORT', 0.09),
#  ('LA CUISINE', 0.07),
#  ('ARTS AND CRAFTS', 0.06),
#  ('FLOWERS', 0.06),
#  ('PC GAMER', 0.05),
#  ('HOUSE COMFORT 2', 0.04),
#  ('CDS MUSIC DVDS', 0.03),
#  ("FASHION CHILDREN'S CLOTHING", 0.02),
#  ('INSURANCE AND SERVICES', 0.01)]

# %% [markdown]
# # Identify the correlation between product price and the number of times a product has been purchased.

# %%
import numpy as np

# %%
query = """ select products.product_category,
count(order_items.product_id),
round(avg(order_items.price),2)
from products join order_items
on products.product_id = order_items.product_id
group by products.product_category
"""

cur.execute(query)

data = cur.fetchall()
df = pd.DataFrame(data, columns = ["Category", "order_count", "price"])

arr1 = df["order_count"]
arr2 = df["price"]

a = np.corrcoef([arr1, arr2])

a[0][1]
# Out:
# -0.10631514167157562

# %% [markdown]
# # Calculate the total revenue generated by each seller, and rank them by revenue.

# %%
query = """ select *, dense_rank() over(order by revenue desc)as rn from
(select order_items.seller_id, sum(payments.payment_value)
revenue from order_items join payments
on order_items.order_id = payments.order_id
group by order_items.seller_id) as a
"""

cur.execute(query)

data = cur.fetchall()
data
df = pd.DataFrame(data, columns = ["seller_id", "revenue", "ranks"])
df = df.head()
sns.barplot(x = df["seller_id"], y = df["revenue"], data = df)
plt.show()

# %% [markdown]
# #  Calculate the moving average of order values for each customer over their order history.

# %%
query = """ select customer_id, order_purchase_timestamp, payment, 
avg(payment) over(partition by customer_id order by order_purchase_timestamp
rows between 2 preceding and current row) as mov_avg
from
(select orders.customer_id, orders.order_purchase_timestamp,
payments.payment_value as payment
from payments join orders
on payments.order_id = orders.order_id) as a
"""

cur.execute(query)

data = cur.fetchall()
data
# Out:
# [('00012a2ce6f8dcda20d059ce98491703',
#   '2017-11-14 16:08:26',
#   114.74,
#   114.73999786376953),
#  ('00012a2ce6f8dcda20d059ce98491703',
#   '2017-11-14 16:08:26',
#   114.74,
#   114.73999786376953),
#  ('00012a2ce6f8dcda20d059ce98491703',
#   '2017-11-14 16:08:26',
#   114.74,
#   114.73999786376953),
#  ('00012a2ce6f8dcda20d059ce98491703',
#   '2017-11-14 16:08:26',
#   114.74,
#   114.73999786376953),
#  ('000161a058600d5901f007fab4c27140',
#   '2017-07-16 09:40:32',
#   67.41,
#   67.41000366210938),
#  ('000161a058600d5901f007fab4c27140',
#   '2017-07-16 09:40:32',
#   67.41,
#   67.41000366210938),
#  ('000161a058600d5901f007fab4c27140',
#   '2017-07-16 09:40:32',
#   67.41,
#   67.41000366210938),
#  ('000161a058600d5901f007fab4c27140',
#   '2017-07-16 09:40:32',
#   67.41,
#   67.41000366210938),
#  ('0001fd6190edaaf884bcaf3d49edf079',
#   '2017-02-28 11:06:43',
#   195.42,
#   195.4199981689453),
#  ('0001fd6190edaaf884bcaf3d49edf079',
#   '2017-02-28 11:06:43',
#   195.42,
#   195.4199981689453),
#  ('0001fd6190edaaf884bcaf3d49edf079',
#   '2017-02-28 11:06:43',
#   195.42,
#   195.4199981689453),
#  ('0001fd6190edaaf884bcaf3d49edf079',
#   '2017-02-28 11:06:43',
#   195.42,
#   195.4199981689453),
#  ('0002414f95344307404f0ace7a26f1d5',
#   '2017-08-16 13:09:20',
#   179.35,
#   179.35000610351562),
#  ('0002414f95344307404f0ace7a26f1d5',
#   '2017-08-16 13:09:20',
#   179.35,
#   179.35000610351562),
#  ('0002414f95344307404f0ace7a26f1d5',
#   '2017-08-16 13:09:20',
#   179.35,
#   179.35000610351562),
#  ('0002414f95344307404f0ace7a26f1d5',
#   '2017-08-16 13:09:20',
#   179.35,
#   179.35000610351562),
#  ('000379cdec625522490c315e70c7a9fb',
#   '2018-04-02 13:42:17',
#   107.01,
#   107.01000213623047),
#  ('000379cdec625522490c315e70c7a9fb',
#   '2018-04-02 13:42:17',
#   107.01,
#   107.01000213623047),
#  ('000379cdec625522490c315e70c7a9fb',
#   '2018-04-02 13:42:17',
#   107.01,
#   107.01000213623047),
#  ('000379cdec625522490c315e70c7a9fb',
#   '2018-04-02 13:42:17',
#   107.01,
#   107.01000213623047),
#  ('0004164d20a9e969af783496f3408652',
#   '2017-04-12 08:35:12',
#   71.8,
#   71.80000305175781),
#  ('0004164d20a9e969af783496f3408652',
#   '2017-04-12 08:35:12',
#   71.8,
#   71.80000305175781),
#  ('0004164d20a9e969af783496f3408652',
#   '2017-04-12 08:35:12',
#   71.8,
#   71.80000305175781),
#  ('0004164d20a9e969af783496f3408652',
#   '2017-04-12 08:35:12',
#   71.8,
#   71.80000305175781),
#  ('000419c5494106c306a97b5635748086',
#   '2018-03-02 17:47:40',
#   49.4,
#   49.400001525878906),
#  ('000419c5494106c306a97b5635748086',
#   '2018-03-02 17:47:40',
#   49.4,
#   49.400001525878906),
#  ('000419c5494106c306a97b5635748086',
#   '2018-03-02 17:47:40',
#   49.4,
#   49.400001525878906),
#  ('000419c5494106c306a97b5635748086',
#   '2018-03-02 17:47:40',
#   49.4,
#   49.400001525878906),
#  ('00046a560d407e99b969756e0b10f282',
#   '2017-12-18 11:08:30',
#   166.59,
#   166.58999633789062),
#  ('00046a560d407e99b969756e0b10f282',
#   '2017-12-18 11:08:30',
#   166.59,
#   166.58999633789062),
#  ('00046a560d407e99b969756e0b10f282',
#   '2017-12-18 11:08:30',
#   166.59,
#   166.58999633789062),
#  ('00046a560d407e99b969756e0b10f282',
#   '2017-12-18 11:08:30',
#   166.59,
#   166.58999633789062),
#  ('00050bf6e01e69d5c0fd612f1bcfb69c',
#   '2017-09-17 16:04:44',
#   85.23,
#   85.2300033569336),
#  ('00050bf6e01e69d5c0fd612f1bcfb69c',
#   '2017-09-17 16:04:44',
#   85.23,
#   85.2300033569336),
#  ('00050bf6e01e69d5c0fd612f1bcfb69c',
#   '2017-09-17 16:04:44',
#   85.23,
#   85.2300033569336),
#  ('00050bf6e01e69d5c0fd612f1bcfb69c',
#   '2017-09-17 16:04:44',
#   85.23,
#   85.2300033569336),
#  ('000598caf2ef4117407665ac33275130',
#   '2018-08-11 12:14:35',
#   1255.71,
#   1255.7099609375),
#  ('000598caf2ef4117407665ac33275130',
#   '2018-08-11 12:14:35',
#   1255.71,
#   1255.7099609375),
#  ('000598caf2ef4117407665ac33275130',
#   '2018-08-11 12:14:35',
#   1255.71,
#   1255.7099609375),
#  ('000598caf2ef4117407665ac33275130',
#   '2018-08-11 12:14:35',
#   1255.71,
#   1255.7099609375),
#  ('0005aefbb696d34b3424dccd0a0e9fd0',
#   '2018-06-20 09:46:53',
#   147.33,
#   147.3300018310547),
#  ('0005aefbb696d34b3424dccd0a0e9fd0',
#   '2018-06-20 09:46:53',
#   147.33,
#   147.3300018310547),
#  ('0005aefbb696d34b3424dccd0a0e9fd0',
#   '2018-06-20 09:46:53',
#   147.33,
#   147.3300018310547),
#  ('0005aefbb696d34b3424dccd0a0e9fd0',
#   '2018-06-20 09:46:53',
#   147.33,
#   147.3300018310547),
#  ('00062b33cb9f6fe976afdcff967ea74d',
#   '2017-03-15 23:44:09',
#   58.95,
#   58.95000076293945),
#  ('00062b33cb9f6fe976afdcff967ea74d',
#   '2017-03-15 23:44:09',
#   58.95,
#   58.95000076293945),
#  ('00062b33cb9f6fe976afdcff967ea74d',
#   '2017-03-15 23:44:09',
#   58.95,
#   58.95000076293945),
#  ('00062b33cb9f6fe976afdcff967ea74d',
#   '2017-03-15 23:44:09',
#   58.95,
#   58.95000076293945),
#  ('00066ccbe787a588c52bd5ff404590e3', '2018-02-06 16:10:09', 270.0, 270.0),
#  ('00066ccbe787a588c52bd5ff404590e3', '2018-02-06 16:10:09', 270.0, 270.0),
#  ('00066ccbe787a588c52bd5ff404590e3', '2018-02-06 16:10:09', 270.0, 270.0),
#  ('00066ccbe787a588c52bd5ff404590e3', '2018-02-06 16:10:09', 270.0, 270.0),
#  ('00072d033fe2e59061ae5c3aff1a2be5',
#   '2017-09-01 09:24:39',
#   106.97,
#   106.97000122070312),
#  ('00072d033fe2e59061ae5c3aff1a2be5',
#   '2017-09-01 09:24:39',
#   106.97,
#   106.97000122070312),
#  ('00072d033fe2e59061ae5c3aff1a2be5',
#   '2017-09-01 09:24:39',
#   106.97,
#   106.97000122070312),
#  ('00072d033fe2e59061ae5c3aff1a2be5',
#   '2017-09-01 09:24:39',
#   106.97,
#   106.97000122070312),
#  ('0009a69b72033b2d0ec8c69fc70ef768',
#   '2017-04-28 13:36:30',
#   173.6,
#   173.60000610351562),
#  ('0009a69b72033b2d0ec8c69fc70ef768',
#   '2017-04-28 13:36:30',
#   173.6,
#   173.60000610351562),
#  ('0009a69b72033b2d0ec8c69fc70ef768',
#   '2017-04-28 13:36:30',
#   173.6,
#   173.60000610351562),
#  ('0009a69b72033b2d0ec8c69fc70ef768',
#   '2017-04-28 13:36:30',
#   173.6,
#   173.60000610351562),
#  ('000bf8121c3412d3057d32371c5d3395',
#   '2017-10-11 07:44:31',
#   45.56,
#   45.560001373291016),
#  ('000bf8121c3412d3057d32371c5d3395',
#   '2017-10-11 07:44:31',
#   45.56,
#   45.560001373291016),
#  ('000bf8121c3412d3057d32371c5d3395',
#   '2017-10-11 07:44:31',
#   45.56,
#   45.560001373291016),
#  ('000bf8121c3412d3057d32371c5d3395',
#   '2017-10-11 07:44:31',
#   45.56,
#   45.560001373291016),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.799999237060547),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.799999237060547),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.799999237060547),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   25.83,
#   26.47666613260905),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   25.83,
#   26.15333302815755),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.15333302815755),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.47666613260905),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.799999237060547),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.799999237060547),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.799999237060547),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.799999237060547),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   25.83,
#   26.47666613260905),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   25.83,
#   26.15333302815755),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.15333302815755),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.47666613260905),
#  ('000e943451fc2788ca6ac98a682f2f49',
#   '2017-04-20 19:37:14',
#   26.8,
#   26.799999237060547),
#  ('000f17e290c26b28549908a04cfe36c1',
#   '2017-11-10 16:37:05',
#   139.52,
#   139.52000427246094),
#  ('000f17e290c26b28549908a04cfe36c1',
#   '2017-11-10 16:37:05',
#   139.52,
#   139.52000427246094),
#  ('000f17e290c26b28549908a04cfe36c1',
#   '2017-11-10 16:37:05',
#   139.52,
#   139.52000427246094),
#  ('000f17e290c26b28549908a04cfe36c1',
#   '2017-11-10 16:37:05',
#   139.52,
#   139.52000427246094),
#  ('000fd45d6fedae68fc6676036610f879',
#   '2018-04-15 15:55:01',
#   66.81,
#   66.80999755859375),
#  ('000fd45d6fedae68fc6676036610f879',
#   '2018-04-15 15:55:01',
#   66.81,
#   66.80999755859375),
#  ('000fd45d6fedae68fc6676036610f879',
#   '2018-04-15 15:55:01',
#   66.81,
#   66.80999755859375),
#  ('000fd45d6fedae68fc6676036610f879',
#   '2018-04-15 15:55:01',
#   66.81,
#   66.80999755859375),
#  ('0010068a73b7c56da5758c3f9e5c7375',
#   '2017-04-11 18:19:55',
#   54.83,
#   54.83000183105469),
#  ('0010068a73b7c56da5758c3f9e5c7375',
#   '2017-04-11 18:19:55',
#   54.83,
#   54.83000183105469),
#  ('0010068a73b7c56da5758c3f9e5c7375',
#   '2017-04-11 18:19:55',
#   54.83,
#   54.83000183105469),
#  ('0010068a73b7c56da5758c3f9e5c7375',
#   '2017-04-11 18:19:55',
#   54.83,
#   54.83000183105469),
#  ('001028b78fd413e19704b3867c369d3a',
#   '2018-04-12 12:51:28',
#   37.61,
#   37.61000061035156),
#  ('001028b78fd413e19704b3867c369d3a',
#   '2018-04-12 12:51:28',
#   37.61,
#   37.61000061035156),
#  ('001028b78fd413e19704b3867c369d3a',
#   '2018-04-12 12:51:28',
#   37.61,
#   37.61000061035156),
#  ('001028b78fd413e19704b3867c369d3a',
#   '2018-04-12 12:51:28',
#   37.61,
#   37.61000061035156),
#  ('00104a47c29da701ce41ee52077587d9',
#   '2018-01-14 20:28:56',
#   100.34,
#   100.33999633789062),
#  ('00104a47c29da701ce41ee52077587d9',
#   '2018-01-14 20:28:56',
#   100.34,
#   100.33999633789062),
#  ('00104a47c29da701ce41ee52077587d9',
#   '2018-01-14 20:28:56',
#   100.34,
#   100.33999633789062),
#  ('00104a47c29da701ce41ee52077587d9',
#   '2018-01-14 20:28:56',
#   100.34,
#   100.33999633789062),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   13.35,
#   13.350000381469727),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   13.35,
#   13.350000381469727),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   19.82,
#   15.506666819254557),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   19.82,
#   17.663333257039387),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   32.03,
#   23.889999389648438),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   32.03,
#   27.959999084472656),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   32.03,
#   32.029998779296875),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   19.82,
#   27.959999084472656),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   32.03,
#   27.959999084472656),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   19.82,
#   23.889999389648438),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   13.35,
#   21.733332951863606),
#  ('001051abfcfdbed9f87b4266213a5df1',
#   '2018-05-30 09:19:31',
#   13.35,
#   15.506666819254557),
#  ('00114026c1b7b52ab1773f317ef4880b',
#   '2017-06-01 19:44:44',
#   66.01,
#   66.01000213623047),
#  ('00114026c1b7b52ab1773f317ef4880b',
#   '2017-06-01 19:44:44',
#   66.01,
#   66.01000213623047),
#  ('00114026c1b7b52ab1773f317ef4880b',
#   '2017-06-01 19:44:44',
#   66.01,
#   66.01000213623047),
#  ('00114026c1b7b52ab1773f317ef4880b',
#   '2017-06-01 19:44:44',
#   66.01,
#   66.01000213623047),
#  ('001226b2341ef620415ce7bbafcfac28',
#   '2017-09-29 01:15:08',
#   47.53,
#   47.529998779296875),
#  ('001226b2341ef620415ce7bbafcfac28',
#   '2017-09-29 01:15:08',
#   47.53,
#   47.529998779296875),
#  ('001226b2341ef620415ce7bbafcfac28',
#   '2017-09-29 01:15:08',
#   47.53,
#   47.529998779296875),
#  ('001226b2341ef620415ce7bbafcfac28',
#   '2017-09-29 01:15:08',
#   47.53,
#   47.529998779296875),
#  ('0012a5c13793cf51e253f096a7e740dd',
#   '2018-03-05 14:54:23',
#   369.92,
#   369.9200134277344),
#  ('0012a5c13793cf51e253f096a7e740dd',
#   '2018-03-05 14:54:23',
#   369.92,
#   369.9200134277344),
#  ('0012a5c13793cf51e253f096a7e740dd',
#   '2018-03-05 14:54:23',
#   369.92,
#   369.9200134277344),
#  ('0012a5c13793cf51e253f096a7e740dd',
#   '2018-03-05 14:54:23',
#   369.92,
#   369.9200134277344),
#  ('0013280441d86a4f7a8006efdaf1b0fe',
#   '2018-01-08 02:35:36',
#   162.15,
#   162.14999389648438),
#  ('0013280441d86a4f7a8006efdaf1b0fe',
#   '2018-01-08 02:35:36',
#   162.15,
#   162.14999389648438),
#  ('0013280441d86a4f7a8006efdaf1b0fe',
#   '2018-01-08 02:35:36',
#   162.15,
#   162.14999389648438),
#  ('0013280441d86a4f7a8006efdaf1b0fe',
#   '2018-01-08 02:35:36',
#   162.15,
#   162.14999389648438),
#  ('0013cd8e350a7cc76873441e431dd5ee',
#   '2018-05-07 23:25:09',
#   92.6,
#   92.5999984741211),
#  ('0013cd8e350a7cc76873441e431dd5ee',
#   '2018-05-07 23:25:09',
#   92.6,
#   92.5999984741211),
#  ('0013cd8e350a7cc76873441e431dd5ee',
#   '2018-05-07 23:25:09',
#   92.6,
#   92.5999984741211),
#  ('0013cd8e350a7cc76873441e431dd5ee',
#   '2018-05-07 23:25:09',
#   92.6,
#   92.5999984741211),
#  ('001450ebb4a77efb3d68be5f7887cb1e',
#   '2018-02-26 08:35:13',
#   61.33,
#   61.33000183105469),
#  ('001450ebb4a77efb3d68be5f7887cb1e',
#   '2018-02-26 08:35:13',
#   61.33,
#   61.33000183105469),
#  ('001450ebb4a77efb3d68be5f7887cb1e',
#   '2018-02-26 08:35:13',
#   61.33,
#   61.33000183105469),
#  ('001450ebb4a77efb3d68be5f7887cb1e',
#   '2018-02-26 08:35:13',
#   61.33,
#   61.33000183105469),
#  ('00146ad30454993879adaa91c518f68c',
#   '2018-01-08 20:40:57',
#   221.79,
#   221.7899932861328),
#  ('00146ad30454993879adaa91c518f68c',
#   '2018-01-08 20:40:57',
#   221.79,
#   221.7899932861328),
#  ('00146ad30454993879adaa91c518f68c',
#   '2018-01-08 20:40:57',
#   221.79,
#   221.7899932861328),
#  ('00146ad30454993879adaa91c518f68c',
#   '2018-01-08 20:40:57',
#   221.79,
#   221.7899932861328),
#  ('00155f0530cc7b2bf73cc3f81cb01c52', '2017-05-14 23:55:13', 40.75, 40.75),
#  ('00155f0530cc7b2bf73cc3f81cb01c52', '2017-05-14 23:55:13', 40.75, 40.75),
#  ('00155f0530cc7b2bf73cc3f81cb01c52', '2017-05-14 23:55:13', 40.75, 40.75),
#  ('00155f0530cc7b2bf73cc3f81cb01c52', '2017-05-14 23:55:13', 40.75, 40.75),
#  ('001574cd5824c0b1ea90dd4f4ba6d5b8',
#   '2017-11-26 02:13:57',
#   184.94,
#   184.94000244140625),
#  ('001574cd5824c0b1ea90dd4f4ba6d5b8',
#   '2017-11-26 02:13:57',
#   184.94,
#   184.94000244140625),
#  ('001574cd5824c0b1ea90dd4f4ba6d5b8',
#   '2017-11-26 02:13:57',
#   184.94,
#   184.94000244140625),
#  ('001574cd5824c0b1ea90dd4f4ba6d5b8',
#   '2017-11-26 02:13:57',
#   184.94,
#   184.94000244140625),
#  ('0015bc9fd2d5395446143e8b215d7c75',
#   '2018-06-11 19:48:34',
#   132.19,
#   132.19000244140625),
#  ('0015bc9fd2d5395446143e8b215d7c75',
#   '2018-06-11 19:48:34',
#   132.19,
#   132.19000244140625),
#  ('0015bc9fd2d5395446143e8b215d7c75',
#   '2018-06-11 19:48:34',
#   132.19,
#   132.19000244140625),
#  ('0015bc9fd2d5395446143e8b215d7c75',
#   '2018-06-11 19:48:34',
#   132.19,
#   132.19000244140625),
#  ('0015f7887e2fde13ddaa7b8e385af919',
#   '2017-07-31 11:05:46',
#   186.74,
#   186.74000549316406),
#  ('0015f7887e2fde13ddaa7b8e385af919',
#   '2017-07-31 11:05:46',
#   186.74,
#   186.74000549316406),
#  ('0015f7887e2fde13ddaa7b8e385af919',
#   '2017-07-31 11:05:46',
#   186.74,
#   186.74000549316406),
#  ('0015f7887e2fde13ddaa7b8e385af919',
#   '2017-07-31 11:05:46',
#   186.74,
#   186.74000549316406),
#  ('0017a0b4c1f1bdb9c395fa0ac517109c',
#   '2018-03-03 18:44:01',
#   50.01,
#   50.0099983215332),
#  ('0017a0b4c1f1bdb9c395fa0ac517109c',
#   '2018-03-03 18:44:01',
#   50.01,
#   50.0099983215332),
#  ('0017a0b4c1f1bdb9c395fa0ac517109c',
#   '2018-03-03 18:44:01',
#   50.01,
#   50.0099983215332),
#  ('0017a0b4c1f1bdb9c395fa0ac517109c',
#   '2018-03-03 18:44:01',
#   50.01,
#   50.0099983215332),
#  ('0018c09f333634ca9c80d9ff46e43e9c',
#   '2018-07-01 18:07:57',
#   56.87,
#   56.869998931884766),
#  ('0018c09f333634ca9c80d9ff46e43e9c',
#   '2018-07-01 18:07:57',
#   56.87,
#   56.869998931884766),
#  ('0018c09f333634ca9c80d9ff46e43e9c',
#   '2018-07-01 18:07:57',
#   56.87,
#   56.869998931884766),
#  ('0018c09f333634ca9c80d9ff46e43e9c',
#   '2018-07-01 18:07:57',
#   56.87,
#   56.869998931884766),
#  ('0018f7fde63ca77254dbc47f4ea358b2',
#   '2017-09-26 14:01:47',
#   51.27,
#   51.27000045776367),
#  ('0018f7fde63ca77254dbc47f4ea358b2',
#   '2017-09-26 14:01:47',
#   51.27,
#   51.27000045776367),
#  ('0018f7fde63ca77254dbc47f4ea358b2',
#   '2017-09-26 14:01:47',
#   51.27,
#   51.27000045776367),
#  ('0018f7fde63ca77254dbc47f4ea358b2',
#   '2017-09-26 14:01:47',
#   51.27,
#   51.27000045776367),
#  ('0019c9aaad15b043c48f0a1180f22ce8',
#   '2018-03-06 00:26:58',
#   112.83,
#   112.83000183105469),
#  ('0019c9aaad15b043c48f0a1180f22ce8',
#   '2018-03-06 00:26:58',
#   112.83,
#   112.83000183105469),
#  ('0019c9aaad15b043c48f0a1180f22ce8',
#   '2018-03-06 00:26:58',
#   112.83,
#   112.83000183105469),
#  ('0019c9aaad15b043c48f0a1180f22ce8',
#   '2018-03-06 00:26:58',
#   112.83,
#   112.83000183105469),
#  ('001a57041f56400917a187dd74e6cbc1',
#   '2018-01-17 21:22:51',
#   53.72,
#   53.720001220703125),
#  ('001a57041f56400917a187dd74e6cbc1',
#   '2018-01-17 21:22:51',
#   53.72,
#   53.720001220703125),
#  ('001a57041f56400917a187dd74e6cbc1',
#   '2018-01-17 21:22:51',
#   53.72,
#   53.720001220703125),
#  ('001a57041f56400917a187dd74e6cbc1',
#   '2018-01-17 21:22:51',
#   53.72,
#   53.720001220703125),
#  ('001b4e9b73aa98a6276b241bfd496822',
#   '2018-04-07 02:12:51',
#   82.87,
#   82.87000274658203),
#  ('001b4e9b73aa98a6276b241bfd496822',
#   '2018-04-07 02:12:51',
#   82.87,
#   82.87000274658203),
#  ('001b4e9b73aa98a6276b241bfd496822',
#   '2018-04-07 02:12:51',
#   82.87,
#   82.87000274658203),
#  ('001b4e9b73aa98a6276b241bfd496822',
#   '2018-04-07 02:12:51',
#   82.87,
#   82.87000274658203),
#  ('001c7f05398c45b42eee0d5a77783bca',
#   '2018-04-12 13:41:07',
#   21.94,
#   21.940000534057617),
#  ('001c7f05398c45b42eee0d5a77783bca',
#   '2018-04-12 13:41:07',
#   21.94,
#   21.940000534057617),
#  ('001c7f05398c45b42eee0d5a77783bca',
#   '2018-04-12 13:41:07',
#   21.94,
#   21.940000534057617),
#  ('001c7f05398c45b42eee0d5a77783bca',
#   '2018-04-12 13:41:07',
#   21.94,
#   21.940000534057617),
#  ('001df1ee5c36767aa607001ab1a13a06',
#   '2018-08-05 23:14:45',
#   42.86,
#   42.86000061035156),
#  ('001df1ee5c36767aa607001ab1a13a06',
#   '2018-08-05 23:14:45',
#   42.86,
#   42.86000061035156),
#  ('001df1ee5c36767aa607001ab1a13a06',
#   '2018-08-05 23:14:45',
#   42.86,
#   42.86000061035156),
#  ('001df1ee5c36767aa607001ab1a13a06',
#   '2018-08-05 23:14:45',
#   42.86,
#   42.86000061035156),
#  ('001f150aebb5d897f2059b0460c38449',
#   '2018-05-09 12:06:04',
#   125.97,
#   125.97000122070312),
#  ('001f150aebb5d897f2059b0460c38449',
#   '2018-05-09 12:06:04',
#   125.97,
#   125.97000122070312),
#  ('001f150aebb5d897f2059b0460c38449',
#   '2018-05-09 12:06:04',
#   125.97,
#   125.97000122070312),
#  ('001f150aebb5d897f2059b0460c38449',
#   '2018-05-09 12:06:04',
#   125.97,
#   125.97000122070312),
#  ('001f35d9f262c558fd065346fbf5801d',
#   '2018-01-25 17:33:55',
#   46.53,
#   46.529998779296875),
#  ('001f35d9f262c558fd065346fbf5801d',
#   '2018-01-25 17:33:55',
#   46.53,
#   46.529998779296875),
#  ('001f35d9f262c558fd065346fbf5801d',
#   '2018-01-25 17:33:55',
#   46.53,
#   46.529998779296875),
#  ('001f35d9f262c558fd065346fbf5801d',
#   '2018-01-25 17:33:55',
#   46.53,
#   46.529998779296875),
#  ('001f6f1a5e902ad14e1f709a7215de11',
#   '2017-02-07 20:32:13',
#   34.86,
#   34.86000061035156),
#  ('001f6f1a5e902ad14e1f709a7215de11',
#   '2017-02-07 20:32:13',
#   34.86,
#   34.86000061035156),
#  ('001f6f1a5e902ad14e1f709a7215de11',
#   '2017-02-07 20:32:13',
#   34.86,
#   34.86000061035156),
#  ('001f6f1a5e902ad14e1f709a7215de11',
#   '2017-02-07 20:32:13',
#   34.86,
#   34.86000061035156),
#  ('00205ad9ba1ef4340cef86583294cf82',
#   '2018-05-12 17:51:47',
#   928.7,
#   928.7000122070312),
#  ('00205ad9ba1ef4340cef86583294cf82',
#   '2018-05-12 17:51:47',
#   928.7,
#   928.7000122070312),
#  ('00205ad9ba1ef4340cef86583294cf82',
#   '2018-05-12 17:51:47',
#   928.7,
#   928.7000122070312),
#  ('00205ad9ba1ef4340cef86583294cf82',
#   '2018-05-12 17:51:47',
#   928.7,
#   928.7000122070312),
#  ('002236c4f333bc8df6a5939749eb7869',
#   '2018-01-22 20:16:33',
#   69.84,
#   69.83999633789062),
#  ('002236c4f333bc8df6a5939749eb7869',
#   '2018-01-22 20:16:33',
#   69.84,
#   69.83999633789062),
#  ('002236c4f333bc8df6a5939749eb7869',
#   '2018-01-22 20:16:33',
#   69.84,
#   69.83999633789062),
#  ('002236c4f333bc8df6a5939749eb7869',
#   '2018-01-22 20:16:33',
#   69.84,
#   69.83999633789062),
#  ('002348c1099e3229276c8ad7d4ddc702',
#   '2018-01-10 12:28:22',
#   249.56,
#   249.55999755859375),
#  ('002348c1099e3229276c8ad7d4ddc702',
#   '2018-01-10 12:28:22',
#   249.56,
#   249.55999755859375),
#  ('002348c1099e3229276c8ad7d4ddc702',
#   '2018-01-10 12:28:22',
#   249.56,
#   249.55999755859375),
#  ('002348c1099e3229276c8ad7d4ddc702',
#   '2018-01-10 12:28:22',
#   249.56,
#   249.55999755859375),
#  ('002408f390f729598bbac1ef9421c6ae',
#   '2018-01-10 17:01:34',
#   258.01,
#   258.010009765625),
#  ('002408f390f729598bbac1ef9421c6ae',
#   '2018-01-10 17:01:34',
#   258.01,
#   258.010009765625),
#  ('002408f390f729598bbac1ef9421c6ae',
#   '2018-01-10 17:01:34',
#   258.01,
#   258.010009765625),
#  ('002408f390f729598bbac1ef9421c6ae',
#   '2018-01-10 17:01:34',
#   258.01,
#   258.010009765625),
#  ('002450e9ea44cb90b8a07ba0b197e149', '2017-08-16 09:07:13', 40.0, 40.0),
#  ('002450e9ea44cb90b8a07ba0b197e149', '2017-08-16 09:07:13', 40.0, 40.0),
#  ('002450e9ea44cb90b8a07ba0b197e149', '2017-08-16 09:07:13', 40.0, 40.0),
#  ('002450e9ea44cb90b8a07ba0b197e149', '2017-08-16 09:07:13', 40.0, 40.0),
#  ('002554bdf9eb99618d8189c3a89fdd52',
#   '2018-08-13 17:59:25',
#   244.08,
#   244.0800018310547),
#  ('002554bdf9eb99618d8189c3a89fdd52',
#   '2018-08-13 17:59:25',
#   244.08,
#   244.0800018310547),
#  ('002554bdf9eb99618d8189c3a89fdd52',
#   '2018-08-13 17:59:25',
#   244.08,
#   244.0800018310547),
#  ('002554bdf9eb99618d8189c3a89fdd52',
#   '2018-08-13 17:59:25',
#   244.08,
#   244.0800018310547),
#  ('0026955706fd4e2fa997f3f4c18d485a',
#   '2018-08-20 11:23:45',
#   121.9,
#   121.9000015258789),
#  ('0026955706fd4e2fa997f3f4c18d485a',
#   '2018-08-20 11:23:45',
#   121.9,
#   121.9000015258789),
#  ('0026955706fd4e2fa997f3f4c18d485a',
#   '2018-08-20 11:23:45',
#   121.9,
#   121.9000015258789),
#  ('0026955706fd4e2fa997f3f4c18d485a',
#   '2018-08-20 11:23:45',
#   121.9,
#   121.9000015258789),
#  ('0026d252429f669d454d726e5e956aa1',
#   '2017-11-09 16:08:41',
#   139.15,
#   139.14999389648438),
#  ('0026d252429f669d454d726e5e956aa1',
#   '2017-11-09 16:08:41',
#   139.15,
#   139.14999389648438),
#  ('0026d252429f669d454d726e5e956aa1',
#   '2017-11-09 16:08:41',
#   139.15,
#   139.14999389648438),
#  ('0026d252429f669d454d726e5e956aa1',
#   '2017-11-09 16:08:41',
#   139.15,
#   139.14999389648438),
#  ('002834b4d901534f48d9e9a72047b288',
#   '2017-10-08 17:38:00',
#   214.14,
#   214.13999938964844),
#  ('002834b4d901534f48d9e9a72047b288',
#   '2017-10-08 17:38:00',
#   214.14,
#   214.13999938964844),
#  ('002834b4d901534f48d9e9a72047b288',
#   '2017-10-08 17:38:00',
#   214.14,
#   214.13999938964844),
#  ('002834b4d901534f48d9e9a72047b288',
#   '2017-10-08 17:38:00',
#   214.14,
#   214.13999938964844),
#  ('0028ff36263a86bf679df7c863a0a0ba',
#   '2018-04-12 17:16:49',
#   74.94,
#   74.94000244140625),
#  ('0028ff36263a86bf679df7c863a0a0ba',
#   '2018-04-12 17:16:49',
#   74.94,
#   74.94000244140625),
#  ('0028ff36263a86bf679df7c863a0a0ba',
#   '2018-04-12 17:16:49',
#   74.94,
#   74.94000244140625),
#  ('0028ff36263a86bf679df7c863a0a0ba',
#   '2018-04-12 17:16:49',
#   74.94,
#   74.94000244140625),
#  ('002905287304e28c0218389269b4759b',
#   '2018-07-22 17:13:46',
#   31.7,
#   31.700000762939453),
#  ('002905287304e28c0218389269b4759b',
#   '2018-07-22 17:13:46',
#   31.7,
#   31.700000762939453),
#  ('002905287304e28c0218389269b4759b',
#   '2018-07-22 17:13:46',
#   31.7,
#   31.700000762939453),
#  ('002905287304e28c0218389269b4759b',
#   '2018-07-22 17:13:46',
#   31.7,
#   31.700000762939453),
#  ('002937abdae13680e17dccd3868b4825',
#   '2017-11-24 20:26:39',
#   43.55,
#   43.54999923706055),
#  ('002937abdae13680e17dccd3868b4825',
#   '2017-11-24 20:26:39',
#   43.55,
#   43.54999923706055),
#  ('002937abdae13680e17dccd3868b4825',
#   '2017-11-24 20:26:39',
#   43.55,
#   43.54999923706055),
#  ('002937abdae13680e17dccd3868b4825',
#   '2017-11-24 20:26:39',
#   43.55,
#   43.54999923706055),
#  ('0029cdf064769cabdf3186b54d068c99',
#   '2018-02-04 12:22:30',
#   483.7,
#   483.70001220703125),
#  ('0029cdf064769cabdf3186b54d068c99',
#   '2018-02-04 12:22:30',
#   483.7,
#   483.70001220703125),
#  ('0029cdf064769cabdf3186b54d068c99',
#   '2018-02-04 12:22:30',
#   483.7,
#   483.70001220703125),
#  ('0029cdf064769cabdf3186b54d068c99',
#   '2018-02-04 12:22:30',
#   483.7,
#   483.70001220703125),
#  ('002a10e899b62a460b0116e0b68697ad',
#   '2018-05-05 18:33:24',
#   92.81,
#   92.80999755859375),
#  ('002a10e899b62a460b0116e0b68697ad',
#   '2018-05-05 18:33:24',
#   92.81,
#   92.80999755859375),
#  ('002a10e899b62a460b0116e0b68697ad',
#   '2018-05-05 18:33:24',
#   92.81,
#   92.80999755859375),
#  ('002a10e899b62a460b0116e0b68697ad',
#   '2018-05-05 18:33:24',
#   92.81,
#   92.80999755859375),
#  ('002b24cb2cd0c3e575040dbd278885e3',
#   '2018-05-21 23:17:32',
#   40.22,
#   40.220001220703125),
#  ('002b24cb2cd0c3e575040dbd278885e3',
#   '2018-05-21 23:17:32',
#   40.22,
#   40.220001220703125),
#  ('002b24cb2cd0c3e575040dbd278885e3',
#   '2018-05-21 23:17:32',
#   40.22,
#   40.220001220703125),
#  ('002b24cb2cd0c3e575040dbd278885e3',
#   '2018-05-21 23:17:32',
#   40.22,
#   40.220001220703125),
#  ('002b5342c72978cf0aba6aae1f5d5293',
#   '2018-09-10 17:51:25',
#   51.17,
#   51.16999816894531),
#  ('002b5342c72978cf0aba6aae1f5d5293',
#   '2018-09-10 17:51:25',
#   51.17,
#   51.16999816894531),
#  ('002b5342c72978cf0aba6aae1f5d5293',
#   '2018-09-10 17:51:25',
#   51.17,
#   51.16999816894531),
#  ('002b5342c72978cf0aba6aae1f5d5293',
#   '2018-09-10 17:51:25',
#   51.17,
#   51.16999816894531),
#  ('002c625393dfa194828b462a6ef8cb0b',
#   '2017-11-19 13:22:44',
#   371.87,
#   371.8699951171875),
#  ('002c625393dfa194828b462a6ef8cb0b',
#   '2017-11-19 13:22:44',
#   371.87,
#   371.8699951171875),
#  ('002c625393dfa194828b462a6ef8cb0b',
#   '2017-11-19 13:22:44',
#   371.87,
#   371.8699951171875),
#  ('002c625393dfa194828b462a6ef8cb0b',
#   '2017-11-19 13:22:44',
#   371.87,
#   371.8699951171875),
#  ('002ce108ccf0356ef5c8b1dce3c0ae29',
#   '2018-06-06 17:22:52',
#   185.6,
#   185.60000610351562),
#  ('002ce108ccf0356ef5c8b1dce3c0ae29',
#   '2018-06-06 17:22:52',
#   185.6,
#   185.60000610351562),
#  ('002ce108ccf0356ef5c8b1dce3c0ae29',
#   '2018-06-06 17:22:52',
#   185.6,
#   185.60000610351562),
#  ('002ce108ccf0356ef5c8b1dce3c0ae29',
#   '2018-06-06 17:22:52',
#   185.6,
#   185.60000610351562),
#  ('002d358e2462f87678443706cbf2eb21',
#   '2018-01-31 17:53:18',
#   45.61,
#   45.61000061035156),
#  ('002d358e2462f87678443706cbf2eb21',
#   '2018-01-31 17:53:18',
#   45.61,
#   45.61000061035156),
#  ('002d358e2462f87678443706cbf2eb21',
#   '2018-01-31 17:53:18',
#   45.61,
#   45.61000061035156),
#  ('002d358e2462f87678443706cbf2eb21',
#   '2018-01-31 17:53:18',
#   45.61,
#   45.61000061035156),
#  ('002d597546b2cf44428232c9f237f873',
#   '2018-07-22 09:29:19',
#   117.74,
#   117.73999786376953),
#  ('002d597546b2cf44428232c9f237f873',
#   '2018-07-22 09:29:19',
#   117.74,
#   117.73999786376953),
#  ('002d597546b2cf44428232c9f237f873',
#   '2018-07-22 09:29:19',
#   117.74,
#   117.73999786376953),
#  ('002d597546b2cf44428232c9f237f873',
#   '2018-07-22 09:29:19',
#   117.74,
#   117.73999786376953),
#  ('002ebb669a34b9e79c88efc755e95322',
#   '2018-08-11 12:41:01',
#   133.57,
#   133.57000732421875),
#  ('002ebb669a34b9e79c88efc755e95322',
#   '2018-08-11 12:41:01',
#   133.57,
#   133.57000732421875),
#  ('002ebb669a34b9e79c88efc755e95322',
#   '2018-08-11 12:41:01',
#   133.57,
#   133.57000732421875),
#  ('002ebb669a34b9e79c88efc755e95322',
#   '2018-08-11 12:41:01',
#   133.57,
#   133.57000732421875),
#  ('002ef7e55600d44ead53f7c1644e5222',
#   '2018-06-19 21:08:43',
#   199.02,
#   199.02000427246094),
#  ('002ef7e55600d44ead53f7c1644e5222',
#   '2018-06-19 21:08:43',
#   199.02,
#   199.02000427246094),
#  ('002ef7e55600d44ead53f7c1644e5222',
#   '2018-06-19 21:08:43',
#   199.02,
#   199.02000427246094),
#  ('002ef7e55600d44ead53f7c1644e5222',
#   '2018-06-19 21:08:43',
#   199.02,
#   199.02000427246094),
#  ('002f067b028a3643ad3a0969c7a0f3dc',
#   '2017-10-19 09:31:12',
#   107.84,
#   107.83999633789062),
#  ('002f067b028a3643ad3a0969c7a0f3dc',
#   '2017-10-19 09:31:12',
#   107.84,
#   107.83999633789062),
#  ('002f067b028a3643ad3a0969c7a0f3dc',
#   '2017-10-19 09:31:12',
#   107.84,
#   107.83999633789062),
#  ('002f067b028a3643ad3a0969c7a0f3dc',
#   '2017-10-19 09:31:12',
#   107.84,
#   107.83999633789062),
#  ('002f90a6eb386bc43bc9ba200db31a89',
#   '2017-06-15 23:59:20',
#   153.51,
#   153.50999450683594),
#  ('002f90a6eb386bc43bc9ba200db31a89',
#   '2017-06-15 23:59:20',
#   153.51,
#   153.50999450683594),
#  ('002f90a6eb386bc43bc9ba200db31a89',
#   '2017-06-15 23:59:20',
#   153.51,
#   153.50999450683594),
#  ('002f90a6eb386bc43bc9ba200db31a89',
#   '2017-06-15 23:59:20',
#   153.51,
#   153.50999450683594),
#  ('002fb8fc5ce64f8422fa2fe79986c783',
#   '2017-11-26 23:15:12',
#   67.68,
#   67.68000030517578),
#  ('002fb8fc5ce64f8422fa2fe79986c783',
#   '2017-11-26 23:15:12',
#   67.68,
#   67.68000030517578),
#  ('002fb8fc5ce64f8422fa2fe79986c783',
#   '2017-11-26 23:15:12',
#   67.68,
#   67.68000030517578),
#  ('002fb8fc5ce64f8422fa2fe79986c783',
#   '2017-11-26 23:15:12',
#   67.68,
#   67.68000030517578),
#  ('002ff70a5285669011090c077ef929af',
#   '2018-08-05 13:19:28',
#   81.14,
#   81.13999938964844),
#  ('002ff70a5285669011090c077ef929af',
#   '2018-08-05 13:19:28',
#   81.14,
#   81.13999938964844),
#  ('002ff70a5285669011090c077ef929af',
#   '2018-08-05 13:19:28',
#   81.14,
#   81.13999938964844),
#  ('002ff70a5285669011090c077ef929af',
#   '2018-08-05 13:19:28',
#   81.14,
#   81.13999938964844),
#  ('00302a0b99783c3d1d1e81c616e321e8',
#   '2018-03-26 18:50:44',
#   159.48,
#   159.47999572753906),
#  ('00302a0b99783c3d1d1e81c616e321e8',
#   '2018-03-26 18:50:44',
#   159.48,
#   159.47999572753906),
#  ('00302a0b99783c3d1d1e81c616e321e8',
#   '2018-03-26 18:50:44',
#   159.48,
#   159.47999572753906),
#  ('00302a0b99783c3d1d1e81c616e321e8',
#   '2018-03-26 18:50:44',
#   159.48,
#   159.47999572753906),
#  ('0030aded3a67b29946a128ee8468388e',
#   '2017-11-23 21:18:14',
#   58.59,
#   58.59000015258789),
#  ('0030aded3a67b29946a128ee8468388e',
#   '2017-11-23 21:18:14',
#   58.59,
#   58.59000015258789),
#  ('0030aded3a67b29946a128ee8468388e',
#   '2017-11-23 21:18:14',
#   58.59,
#   58.59000015258789),
#  ('0030aded3a67b29946a128ee8468388e',
#   '2017-11-23 21:18:14',
#   58.59,
#   58.59000015258789),
#  ('0030fbb95fbe7e61f798a80edb01a8e9',
#   '2017-11-09 23:28:29',
#   26.85,
#   26.850000381469727),
#  ('0030fbb95fbe7e61f798a80edb01a8e9',
#   '2017-11-09 23:28:29',
#   26.85,
#   26.850000381469727),
#  ('0030fbb95fbe7e61f798a80edb01a8e9',
#   '2017-11-09 23:28:29',
#   26.85,
#   26.850000381469727),
#  ('0030fbb95fbe7e61f798a80edb01a8e9',
#   '2017-11-09 23:28:29',
#   26.85,
#   26.850000381469727),
#  ('00314f95a054231742e3c5396b333b88',
#   '2018-01-08 19:29:38',
#   59.34,
#   59.34000015258789),
#  ('00314f95a054231742e3c5396b333b88',
#   '2018-01-08 19:29:38',
#   59.34,
#   59.34000015258789),
#  ('00314f95a054231742e3c5396b333b88',
#   '2018-01-08 19:29:38',
#   59.34,
#   59.34000015258789),
#  ('00314f95a054231742e3c5396b333b88',
#   '2018-01-08 19:29:38',
#   59.34,
#   59.34000015258789),
#  ('003177b3eeca50af17750f53802c9a09',
#   '2018-07-08 15:48:40',
#   133.81,
#   133.80999755859375),
#  ('003177b3eeca50af17750f53802c9a09',
#   '2018-07-08 15:48:40',
#   133.81,
#   133.80999755859375),
#  ('003177b3eeca50af17750f53802c9a09',
#   '2018-07-08 15:48:40',
#   133.81,
#   133.80999755859375),
#  ('003177b3eeca50af17750f53802c9a09',
#   '2018-07-08 15:48:40',
#   133.81,
#   133.80999755859375),
#  ('0031abfb953b66e998f67b09e7b11375',
#   '2018-01-23 13:57:55',
#   671.85,
#   671.8499755859375),
#  ('0031abfb953b66e998f67b09e7b11375',
#   '2018-01-23 13:57:55',
#   671.85,
#   671.8499755859375),
#  ('0031abfb953b66e998f67b09e7b11375',
#   '2018-01-23 13:57:55',
#   671.85,
#   671.8499755859375),
#  ('0031abfb953b66e998f67b09e7b11375',
#   '2018-01-23 13:57:55',
#   671.85,
#   671.8499755859375),
#  ('0031c1062edf836ef7a7a7ea758b137b', '2017-03-01 20:00:23', 81.0, 81.0),
#  ('0031c1062edf836ef7a7a7ea758b137b', '2017-03-01 20:00:23', 81.0, 81.0),
#  ('0031c1062edf836ef7a7a7ea758b137b', '2017-03-01 20:00:23', 81.0, 81.0),
#  ('0031c1062edf836ef7a7a7ea758b137b', '2017-03-01 20:00:23', 81.0, 81.0),
#  ('00330644cccc5db0276fa836976306fe',
#   '2017-10-30 17:48:07',
#   55.1,
#   55.099998474121094),
#  ('00330644cccc5db0276fa836976306fe',
#   '2017-10-30 17:48:07',
#   55.1,
#   55.099998474121094),
#  ('00330644cccc5db0276fa836976306fe',
#   '2017-10-30 17:48:07',
#   55.1,
#   55.099998474121094),
#  ('00330644cccc5db0276fa836976306fe',
#   '2017-10-30 17:48:07',
#   55.1,
#   55.099998474121094),
#  ('00331de1659c7f4fb660c8810e6de3f5',
#   '2017-12-18 14:54:52',
#   243.69,
#   243.69000244140625),
#  ('00331de1659c7f4fb660c8810e6de3f5',
#   '2017-12-18 14:54:52',
#   243.69,
#   243.69000244140625),
#  ('00331de1659c7f4fb660c8810e6de3f5',
#   '2017-12-18 14:54:52',
#   243.69,
#   243.69000244140625),
#  ('00331de1659c7f4fb660c8810e6de3f5',
#   '2017-12-18 14:54:52',
#   243.69,
#   243.69000244140625),
#  ('0033823ee55671ac5317d423291333c2',
#   '2017-05-29 19:02:27',
#   79.48,
#   79.4800033569336),
#  ('0033823ee55671ac5317d423291333c2',
#   '2017-05-29 19:02:27',
#   79.48,
#   79.4800033569336),
#  ('0033823ee55671ac5317d423291333c2',
#   '2017-05-29 19:02:27',
#   79.48,
#   79.4800033569336),
#  ('0033823ee55671ac5317d423291333c2',
#   '2017-05-29 19:02:27',
#   79.48,
#   79.4800033569336),
#  ('0034f7933de3ead6bd9ba49afe95f119',
#   '2018-04-06 09:25:10',
#   84.24,
#   84.23999786376953),
#  ('0034f7933de3ead6bd9ba49afe95f119',
#   '2018-04-06 09:25:10',
#   84.24,
#   84.23999786376953),
#  ('0034f7933de3ead6bd9ba49afe95f119',
#   '2018-04-06 09:25:10',
#   84.24,
#   84.23999786376953),
#  ('0034f7933de3ead6bd9ba49afe95f119',
#   '2018-04-06 09:25:10',
#   84.24,
#   84.23999786376953),
#  ('003536ce5e18f1d12b9bf76932f8a6b1',
#   '2017-10-16 19:17:54',
#   53.33,
#   53.33000183105469),
#  ('003536ce5e18f1d12b9bf76932f8a6b1',
#   '2017-10-16 19:17:54',
#   53.33,
#   53.33000183105469),
#  ('003536ce5e18f1d12b9bf76932f8a6b1',
#   '2017-10-16 19:17:54',
#   53.33,
#   53.33000183105469),
#  ('003536ce5e18f1d12b9bf76932f8a6b1',
#   '2017-10-16 19:17:54',
#   53.33,
#   53.33000183105469),
#  ('0035b30e58c620fa2bd30275ddd4f7ef',
#   '2018-04-08 18:56:27',
#   78.2,
#   78.19999694824219),
#  ('0035b30e58c620fa2bd30275ddd4f7ef',
#   '2018-04-08 18:56:27',
#   78.2,
#   78.19999694824219),
#  ('0035b30e58c620fa2bd30275ddd4f7ef',
#   '2018-04-08 18:56:27',
#   78.2,
#   78.19999694824219),
#  ('0035b30e58c620fa2bd30275ddd4f7ef',
#   '2018-04-08 18:56:27',
#   78.2,
#   78.19999694824219),
#  ('0036875772a8eeb391b8cd7226283fdd',
#   '2018-01-21 22:49:14',
#   61.85,
#   61.849998474121094),
#  ('0036875772a8eeb391b8cd7226283fdd',
#   '2018-01-21 22:49:14',
#   61.85,
#   61.849998474121094),
#  ('0036875772a8eeb391b8cd7226283fdd',
#   '2018-01-21 22:49:14',
#   61.85,
#   61.849998474121094),
#  ('0036875772a8eeb391b8cd7226283fdd',
#   '2018-01-21 22:49:14',
#   61.85,
#   61.849998474121094),
#  ('0037d14e53af1d555a582504a4058f4c',
#   '2017-06-11 17:40:22',
#   603.4,
#   603.4000244140625),
#  ('0037d14e53af1d555a582504a4058f4c',
#   '2017-06-11 17:40:22',
#   603.4,
#   603.4000244140625),
#  ('0037d14e53af1d555a582504a4058f4c',
#   '2017-06-11 17:40:22',
#   603.4,
#   603.4000244140625),
#  ('0037d14e53af1d555a582504a4058f4c',
#   '2017-06-11 17:40:22',
#   603.4,
#   603.4000244140625),
#  ('00380c010de38d578d02117f6d0b88e7',
#   '2018-02-28 11:10:46',
#   64.1,
#   64.0999984741211),
#  ('00380c010de38d578d02117f6d0b88e7',
#   '2018-02-28 11:10:46',
#   64.1,
#   64.0999984741211),
#  ('00380c010de38d578d02117f6d0b88e7',
#   '2018-02-28 11:10:46',
#   64.1,
#   64.0999984741211),
#  ('00380c010de38d578d02117f6d0b88e7',
#   '2018-02-28 11:10:46',
#   64.1,
#   64.0999984741211),
#  ('0039b3e41ac6615814a0b44a8992bff5',
#   '2018-01-11 01:24:43',
#   34.59,
#   34.59000015258789),
#  ('0039b3e41ac6615814a0b44a8992bff5',
#   '2018-01-11 01:24:43',
#   34.59,
#   34.59000015258789),
#  ('0039b3e41ac6615814a0b44a8992bff5',
#   '2018-01-11 01:24:43',
#   34.59,
#   34.59000015258789),
#  ('0039b3e41ac6615814a0b44a8992bff5',
#   '2018-01-11 01:24:43',
#   34.59,
#   34.59000015258789),
#  ('003a75d228dc67cb2918e40c2aacc4bf',
#   '2017-10-19 12:07:22',
#   79.28,
#   79.27999877929688),
#  ('003a75d228dc67cb2918e40c2aacc4bf',
#   '2017-10-19 12:07:22',
#   79.28,
#   79.27999877929688),
#  ('003a75d228dc67cb2918e40c2aacc4bf',
#   '2017-10-19 12:07:22',
#   79.28,
#   79.27999877929688),
#  ('003a75d228dc67cb2918e40c2aacc4bf',
#   '2017-10-19 12:07:22',
#   79.28,
#   79.27999877929688),
#  ('003b595c764773e20e0949b6fba7b1dc',
#   '2018-04-14 08:18:05',
#   25.46,
#   25.459999084472656),
#  ('003b595c764773e20e0949b6fba7b1dc',
#   '2018-04-14 08:18:05',
#   25.46,
#   25.459999084472656),
#  ('003b595c764773e20e0949b6fba7b1dc',
#   '2018-04-14 08:18:05',
#   25.46,
#   25.459999084472656),
#  ('003b595c764773e20e0949b6fba7b1dc',
#   '2018-04-14 08:18:05',
#   25.46,
#   25.459999084472656),
#  ('003bc8d06ebed9d146eb9f100d0a89ae',
#   '2018-03-07 15:08:14',
#   600.04,
#   600.0399780273438),
#  ('003bc8d06ebed9d146eb9f100d0a89ae',
#   '2018-03-07 15:08:14',
#   600.04,
#   600.0399780273438),
#  ('003bc8d06ebed9d146eb9f100d0a89ae',
#   '2018-03-07 15:08:14',
#   600.04,
#   600.0399780273438),
#  ('003bc8d06ebed9d146eb9f100d0a89ae',
#   '2018-03-07 15:08:14',
#   600.04,
#   600.0399780273438),
#  ('003bdf7fd8312f9d14a4b979f3747334',
#   '2017-11-28 15:39:53',
#   43.68,
#   43.68000030517578),
#  ('003bdf7fd8312f9d14a4b979f3747334',
#   '2017-11-28 15:39:53',
#   43.68,
#   43.68000030517578),
#  ('003bdf7fd8312f9d14a4b979f3747334',
#   '2017-11-28 15:39:53',
#   43.68,
#   43.68000030517578),
#  ('003bdf7fd8312f9d14a4b979f3747334',
#   '2017-11-28 15:39:53',
#   43.68,
#   43.68000030517578),
#  ('003c7cadba4f182b9f22d7d5ea7a5003', '2018-04-19 11:58:57', 128.25, 128.25),
#  ('003c7cadba4f182b9f22d7d5ea7a5003', '2018-04-19 11:58:57', 128.25, 128.25),
#  ('003c7cadba4f182b9f22d7d5ea7a5003', '2018-04-19 11:58:57', 128.25, 128.25),
#  ('003c7cadba4f182b9f22d7d5ea7a5003', '2018-04-19 11:58:57', 128.25, 128.25),
#  ('003cb2c7ce25d8af8556fb456f903546',
#   '2017-08-12 17:08:34',
#   420.94,
#   420.94000244140625),
#  ('003cb2c7ce25d8af8556fb456f903546',
#   '2017-08-12 17:08:34',
#   420.94,
#   420.94000244140625),
#  ('003cb2c7ce25d8af8556fb456f903546',
#   '2017-08-12 17:08:34',
#   420.94,
#   420.94000244140625),
#  ('003cb2c7ce25d8af8556fb456f903546',
#   '2017-08-12 17:08:34',
#   420.94,
#   420.94000244140625),
#  ('003cbe6a43560a8b6fd2c07531257c2d', '2018-02-01 14:05:22', 27.75, 27.75),
#  ('003cbe6a43560a8b6fd2c07531257c2d', '2018-02-01 14:05:22', 27.75, 27.75),
#  ('003cbe6a43560a8b6fd2c07531257c2d', '2018-02-01 14:05:22', 27.75, 27.75),
#  ('003cbe6a43560a8b6fd2c07531257c2d', '2018-02-01 14:05:22', 27.75, 27.75),
#  ('003e45472805afa1ee701d83284fa22b',
#   '2017-06-11 20:50:58',
#   30.6,
#   30.600000381469727),
#  ('003e45472805afa1ee701d83284fa22b',
#   '2017-06-11 20:50:58',
#   30.6,
#   30.600000381469727),
#  ('003e45472805afa1ee701d83284fa22b',
#   '2017-06-11 20:50:58',
#   30.6,
#   30.600000381469727),
#  ('003e45472805afa1ee701d83284fa22b',
#   '2017-06-11 20:50:58',
#   30.6,
#   30.600000381469727),
#  ('003eab528664e1bd677218ef4be086ac',
#   '2017-04-03 19:20:39',
#   77.1,
#   77.0999984741211),
#  ('003eab528664e1bd677218ef4be086ac',
#   '2017-04-03 19:20:39',
#   77.1,
#   77.0999984741211),
#  ('003eab528664e1bd677218ef4be086ac',
#   '2017-04-03 19:20:39',
#   77.1,
#   77.0999984741211),
#  ('003eab528664e1bd677218ef4be086ac',
#   '2017-04-03 19:20:39',
#   77.1,
#   77.0999984741211),
#  ('003ec17a1389fa302f3a0423dddd8650',
#   '2018-01-14 17:25:31',
#   17.77,
#   17.770000457763672),
#  ('003ec17a1389fa302f3a0423dddd8650',
#   '2018-01-14 17:25:31',
#   17.77,
#   17.770000457763672),
#  ('003ec17a1389fa302f3a0423dddd8650',
#   '2018-01-14 17:25:31',
#   17.77,
#   17.770000457763672),
#  ('003ec17a1389fa302f3a0423dddd8650',
#   '2018-01-14 17:25:31',
#   17.77,
#   17.770000457763672),
#  ('003f7d92ac63c512bb6584219806f8df',
#   '2018-02-14 12:45:19',
#   84.91,
#   84.91000366210938),
#  ('003f7d92ac63c512bb6584219806f8df',
#   '2018-02-14 12:45:19',
#   84.91,
#   84.91000366210938),
#  ('003f7d92ac63c512bb6584219806f8df',
#   '2018-02-14 12:45:19',
#   84.91,
#   84.91000366210938),
#  ('003f7d92ac63c512bb6584219806f8df',
#   '2018-02-14 12:45:19',
#   84.91,
#   84.91000366210938),
#  ('0040a8417928d0d5abd5169cd7877181',
#   '2018-06-27 17:38:07',
#   219.49,
#   219.49000549316406),
#  ('0040a8417928d0d5abd5169cd7877181',
#   '2018-06-27 17:38:07',
#   219.49,
#   219.49000549316406),
#  ('0040a8417928d0d5abd5169cd7877181',
#   '2018-06-27 17:38:07',
#   219.49,
#   219.49000549316406),
#  ('0040a8417928d0d5abd5169cd7877181',
#   '2018-06-27 17:38:07',
#   219.49,
#   219.49000549316406),
#  ('0040b00970e2139e8c43b647c0da5305',
#   '2017-01-26 23:10:07',
#   41.93,
#   41.93000030517578),
#  ('0040b00970e2139e8c43b647c0da5305',
#   '2017-01-26 23:10:07',
#   41.93,
#   41.93000030517578),
#  ('0040b00970e2139e8c43b647c0da5305',
#   '2017-01-26 23:10:07',
#   41.93,
#   41.93000030517578),
#  ('0040b00970e2139e8c43b647c0da5305',
#   '2017-01-26 23:10:07',
#   41.93,
#   41.93000030517578),
#  ('00411811e3b661e746a6e1ce1f0878ab',
#   '2017-05-07 17:27:21',
#   367.2,
#   367.20001220703125),
#  ('00411811e3b661e746a6e1ce1f0878ab',
#   '2017-05-07 17:27:21',
#   367.2,
#   367.20001220703125),
#  ('00411811e3b661e746a6e1ce1f0878ab',
#   '2017-05-07 17:27:21',
#   367.2,
#   367.20001220703125),
#  ('00411811e3b661e746a6e1ce1f0878ab',
#   '2017-05-07 17:27:21',
#   367.2,
#   367.20001220703125),
#  ('0041d7b768cb115092fa0f5d55638d06',
#   '2018-03-10 22:11:27',
#   81.32,
#   81.31999969482422),
#  ('0041d7b768cb115092fa0f5d55638d06',
#   '2018-03-10 22:11:27',
#   81.32,
#   81.31999969482422),
#  ('0041d7b768cb115092fa0f5d55638d06',
#   '2018-03-10 22:11:27',
#   81.32,
#   81.31999969482422),
#  ('0041d7b768cb115092fa0f5d55638d06',
#   '2018-03-10 22:11:27',
#   81.32,
#   81.31999969482422),
#  ('00426311a53f3c052943c88b692a3be2',
#   '2017-12-13 15:35:25',
#   273.66,
#   273.6600036621094),
#  ('00426311a53f3c052943c88b692a3be2',
#   '2017-12-13 15:35:25',
#   273.66,
#   273.6600036621094),
#  ('00426311a53f3c052943c88b692a3be2',
#   '2017-12-13 15:35:25',
#   273.66,
#   273.6600036621094),
#  ('00426311a53f3c052943c88b692a3be2',
#   '2017-12-13 15:35:25',
#   273.66,
#   273.6600036621094),
#  ('0042d04ee8231b36dcb29aac213f5db4',
#   '2017-04-10 21:59:56',
#   33.47,
#   33.470001220703125),
#  ('0042d04ee8231b36dcb29aac213f5db4',
#   '2017-04-10 21:59:56',
#   33.47,
#   33.470001220703125),
#  ('0042d04ee8231b36dcb29aac213f5db4',
#   '2017-04-10 21:59:56',
#   33.47,
#   33.470001220703125),
#  ('0042d04ee8231b36dcb29aac213f5db4',
#   '2017-04-10 21:59:56',
#   33.47,
#   33.470001220703125),
#  ('0043b0afd67fb3af74360d2893b9a530',
#   '2017-11-15 21:06:10',
#   115.45,
#   115.44999694824219),
#  ('0043b0afd67fb3af74360d2893b9a530',
#   '2017-11-15 21:06:10',
#   115.45,
#   115.44999694824219),
#  ('0043b0afd67fb3af74360d2893b9a530',
#   '2017-11-15 21:06:10',
#   115.45,
#   115.44999694824219),
#  ('0043b0afd67fb3af74360d2893b9a530',
#   '2017-11-15 21:06:10',
#   115.45,
#   115.44999694824219),
#  ('004440537b68545ca3c341d7279bc4c0',
#   '2018-08-28 22:30:32',
#   98.04,
#   98.04000091552734),
#  ('004440537b68545ca3c341d7279bc4c0',
#   '2018-08-28 22:30:32',
#   98.04,
#   98.04000091552734),
#  ('004440537b68545ca3c341d7279bc4c0',
#   '2018-08-28 22:30:32',
#   98.04,
#   98.04000091552734),
#  ('004440537b68545ca3c341d7279bc4c0',
#   '2018-08-28 22:30:32',
#   98.04,
#   98.04000091552734),
#  ('00447b6bd39c4a0f6366b05948f9e2e3',
#   '2018-06-25 15:05:27',
#   303.79,
#   303.7900085449219),
#  ('00447b6bd39c4a0f6366b05948f9e2e3',
#   '2018-06-25 15:05:27',
#   303.79,
#   303.7900085449219),
#  ('00447b6bd39c4a0f6366b05948f9e2e3',
#   '2018-06-25 15:05:27',
#   303.79,
#   303.7900085449219),
#  ('00447b6bd39c4a0f6366b05948f9e2e3',
#   '2018-06-25 15:05:27',
#   303.79,
#   303.7900085449219),
#  ('00459c4eb23e40414ca067d06fa303d4',
#   '2018-05-07 15:18:18',
#   87.94,
#   87.94000244140625),
#  ('00459c4eb23e40414ca067d06fa303d4',
#   '2018-05-07 15:18:18',
#   87.94,
#   87.94000244140625),
#  ('00459c4eb23e40414ca067d06fa303d4',
#   '2018-05-07 15:18:18',
#   87.94,
#   87.94000244140625),
#  ('00459c4eb23e40414ca067d06fa303d4',
#   '2018-05-07 15:18:18',
#   87.94,
#   87.94000244140625),
#  ('0045ac1c0957bc92e109f71e4941fa49',
#   '2018-06-30 11:49:28',
#   152.47,
#   152.47000122070312),
#  ('0045ac1c0957bc92e109f71e4941fa49',
#   '2018-06-30 11:49:28',
#   152.47,
#   152.47000122070312),
#  ('0045ac1c0957bc92e109f71e4941fa49',
#   '2018-06-30 11:49:28',
#   152.47,
#   152.47000122070312),
#  ('0045ac1c0957bc92e109f71e4941fa49',
#   '2018-06-30 11:49:28',
#   152.47,
#   152.47000122070312),
#  ('00474d2582fd72663036795b7ab8cfc1',
#   '2016-10-04 22:33:44',
#   108.84,
#   108.83999633789062),
#  ('00474d2582fd72663036795b7ab8cfc1',
#   '2016-10-04 22:33:44',
#   108.84,
#   108.83999633789062),
#  ('00474d2582fd72663036795b7ab8cfc1',
#   '2016-10-04 22:33:44',
#   108.84,
#   108.83999633789062),
#  ('00474d2582fd72663036795b7ab8cfc1',
#   '2016-10-04 22:33:44',
#   108.84,
#   108.83999633789062),
#  ('004937d0f9d6ce15c2830c00c2f482e5',
#   '2018-01-27 17:01:48',
#   6.96,
#   6.960000038146973),
#  ('004937d0f9d6ce15c2830c00c2f482e5',
#   '2018-01-27 17:01:48',
#   63.95,
#   35.45500040054321),
#  ('004937d0f9d6ce15c2830c00c2f482e5',
#   '2018-01-27 17:01:48',
#   63.95,
#   44.95333385467529),
#  ('004937d0f9d6ce15c2830c00c2f482e5',
#   '2018-01-27 17:01:48',
#   6.96,
#   44.95333385467529),
#  ('004937d0f9d6ce15c2830c00c2f482e5',
#   '2018-01-27 17:01:48',
#   6.96,
#   25.956666946411133),
#  ('004937d0f9d6ce15c2830c00c2f482e5',
#   '2018-01-27 17:01:48',
#   6.96,
#   6.960000038146973),
#  ('004937d0f9d6ce15c2830c00c2f482e5',
#   '2018-01-27 17:01:48',
#   63.95,
#   25.956666946411133),
#  ('004937d0f9d6ce15c2830c00c2f482e5',
#   '2018-01-27 17:01:48',
#   63.95,
#   44.95333385467529),
#  ('00498d14e21c58ed2feb5d5feb4cd706',
#   '2018-01-12 22:38:53',
#   106.87,
#   106.87000274658203),
#  ('00498d14e21c58ed2feb5d5feb4cd706',
#   '2018-01-12 22:38:53',
#   106.87,
#   106.87000274658203),
#  ('00498d14e21c58ed2feb5d5feb4cd706',
#   '2018-01-12 22:38:53',
#   106.87,
#   106.87000274658203),
#  ('00498d14e21c58ed2feb5d5feb4cd706',
#   '2018-01-12 22:38:53',
#   106.87,
#   106.87000274658203),
#  ('0049e8442c2a3e4a8d1ff5a9549abd53', '2017-08-28 21:16:10', 600.0, 600.0),
#  ('0049e8442c2a3e4a8d1ff5a9549abd53', '2017-08-28 21:16:10', 600.0, 600.0),
#  ('0049e8442c2a3e4a8d1ff5a9549abd53', '2017-08-28 21:16:10', 600.0, 600.0),
#  ('0049e8442c2a3e4a8d1ff5a9549abd53',
#   '2017-08-28 21:16:10',
#   650.81,
#   616.9366658528646),
#  ('0049e8442c2a3e4a8d1ff5a9549abd53',
#   '2017-08-28 21:16:10',
#   600.0,
#   616.9366658528646),
#  ('0049e8442c2a3e4a8d1ff5a9549abd53',
#   '2017-08-28 21:16:10',
#   650.81,
#   633.8733317057291),
#  ('0049e8442c2a3e4a8d1ff5a9549abd53',
#   '2017-08-28 21:16:10',
#   650.81,
#   633.8733317057291),
#  ('0049e8442c2a3e4a8d1ff5a9549abd53',
#   '2017-08-28 21:16:10',
#   650.81,
#   650.8099975585938),
#  ('004a2b3e8b026284407c620f4f01f686',
#   '2018-04-18 22:19:28',
#   163.78,
#   163.77999877929688),
#  ('004a2b3e8b026284407c620f4f01f686',
#   '2018-04-18 22:19:28',
#   163.78,
#   163.77999877929688),
#  ('004a2b3e8b026284407c620f4f01f686',
#   '2018-04-18 22:19:28',
#   163.78,
#   163.77999877929688),
#  ('004a2b3e8b026284407c620f4f01f686',
#   '2018-04-18 22:19:28',
#   163.78,
#   163.77999877929688),
#  ('004d41e9bf012c669db1a257888d85a2',
#   '2017-07-14 11:00:15',
#   307.24,
#   307.239990234375),
#  ('004d41e9bf012c669db1a257888d85a2',
#   '2017-07-14 11:00:15',
#   307.24,
#   307.239990234375),
#  ('004d41e9bf012c669db1a257888d85a2',
#   '2017-07-14 11:00:15',
#   307.24,
#   307.239990234375),
#  ('004d41e9bf012c669db1a257888d85a2',
#   '2017-07-14 11:00:15',
#   307.24,
#   307.239990234375),
#  ('004df18653e9438571e9d294776a5c5c',
#   '2018-06-04 15:54:53',
#   50.29,
#   50.290000915527344),
#  ('004df18653e9438571e9d294776a5c5c',
#   '2018-06-04 15:54:53',
#   50.29,
#   50.290000915527344),
#  ('004df18653e9438571e9d294776a5c5c',
#   '2018-06-04 15:54:53',
#   50.29,
#   50.290000915527344),
#  ('004df18653e9438571e9d294776a5c5c',
#   '2018-06-04 15:54:53',
#   50.29,
#   50.290000915527344),
#  ('004ee20df425002ed78553e1f50caa3e',
#   '2018-05-01 18:56:48',
#   32.69,
#   32.689998626708984),
#  ('004ee20df425002ed78553e1f50caa3e',
#   '2018-05-01 18:56:48',
#   32.69,
#   32.689998626708984),
#  ('004ee20df425002ed78553e1f50caa3e',
#   '2018-05-01 18:56:48',
#   32.69,
#   32.689998626708984),
#  ('004ee20df425002ed78553e1f50caa3e',
#   '2018-05-01 18:56:48',
#   32.69,
#   32.689998626708984),
#  ('004f39eb181d53fa796fe82ce7a0cbd5',
#   '2018-05-11 17:42:26',
#   98.97,
#   98.97000122070312),
#  ('004f39eb181d53fa796fe82ce7a0cbd5',
#   '2018-05-11 17:42:26',
#   98.97,
#   98.97000122070312),
#  ('004f39eb181d53fa796fe82ce7a0cbd5',
#   '2018-05-11 17:42:26',
#   98.97,
#   98.97000122070312),
#  ('004f39eb181d53fa796fe82ce7a0cbd5',
#   '2018-05-11 17:42:26',
#   98.97,
#   98.97000122070312),
#  ('00502500a53243e07961383bf1a6fa82',
#   '2018-02-20 14:24:58',
#   71.92,
#   71.91999816894531),
#  ('00502500a53243e07961383bf1a6fa82',
#   '2018-02-20 14:24:58',
#   71.92,
#   71.91999816894531),
#  ('00502500a53243e07961383bf1a6fa82',
#   '2018-02-20 14:24:58',
#   71.92,
#   71.91999816894531),
#  ('00502500a53243e07961383bf1a6fa82',
#   '2018-02-20 14:24:58',
#   71.92,
#   71.91999816894531),
#  ('005092c23e81812fbbe11fc6cf7e5316', '2017-08-06 15:45:03', 44.0, 44.0),
#  ('005092c23e81812fbbe11fc6cf7e5316', '2017-08-06 15:45:03', 44.0, 44.0),
#  ('005092c23e81812fbbe11fc6cf7e5316', '2017-08-06 15:45:03', 44.0, 44.0),
#  ('005092c23e81812fbbe11fc6cf7e5316', '2017-08-06 15:45:03', 44.0, 44.0),
#  ('0050b4dd994efa94b2cd3210e4cecf32',
#   '2017-07-11 08:20:00',
#   164.38,
#   164.3800048828125),
# ...
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7', '2017-06-02 21:39:00', 25.0, 25.0),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7', '2017-06-02 21:39:00', 25.0, 25.0),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7', '2017-06-02 21:39:00', 25.0, 25.0),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7', '2017-06-02 21:39:00', 25.0, 25.0),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7',
#   '2017-06-02 21:39:00',
#   260.37,
#   103.4566650390625),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7',
#   '2017-06-02 21:39:00',
#   25.0,
#   103.4566650390625),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7',
#   '2017-06-02 21:39:00',
#   25.0,
#   103.4566650390625),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7',
#   '2017-06-02 21:39:00',
#   260.37,
#   103.4566650390625),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7',
#   '2017-06-02 21:39:00',
#   25.0,
#   103.4566650390625),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7',
#   '2017-06-02 21:39:00',
#   25.0,
#   103.4566650390625),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7', '2017-06-02 21:39:00', 25.0, 25.0),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7', '2017-06-02 21:39:00', 25.0, 25.0),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7', '2017-06-02 21:39:00', 25.0, 25.0),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7',
#   '2017-06-02 21:39:00',
#   260.37,
#   103.4566650390625),
#  ('007e99fec9d53dfa4e5d8be9c2b36ca7',
#   '2017-06-02 21:39:00',
#   260.37,
#   181.913330078125),
#  ('007ff1d42a6a44f0e16e18d2d7d5f72e',
#   '2017-03-30 18:55:59',
#   98.83,
#   98.83000183105469),
#  ('007ff1d42a6a44f0e16e18d2d7d5f72e',
#   '2017-03-30 18:55:59',
#   98.83,
#   98.83000183105469),
#  ('007ff1d42a6a44f0e16e18d2d7d5f72e',
#   '2017-03-30 18:55:59',
#   98.83,
#   98.83000183105469),
#  ('007ff1d42a6a44f0e16e18d2d7d5f72e',
#   '2017-03-30 18:55:59',
#   98.83,
#   98.83000183105469),
#  ('0080e98d82eceee143dc006defe00687',
#   '2017-10-26 18:29:04',
#   72.66,
#   72.66000366210938),
#  ('0080e98d82eceee143dc006defe00687',
#   '2017-10-26 18:29:04',
#   72.66,
#   72.66000366210938),
#  ('0080e98d82eceee143dc006defe00687',
#   '2017-10-26 18:29:04',
#   72.66,
#   72.66000366210938),
#  ('0080e98d82eceee143dc006defe00687',
#   '2017-10-26 18:29:04',
#   72.66,
#   72.66000366210938),
#  ('00838729460c2110a0bd330a4bb9b332', '2018-03-24 07:54:34', 50.0, 50.0),
#  ('00838729460c2110a0bd330a4bb9b332', '2018-03-24 07:54:34', 50.0, 50.0),
#  ('00838729460c2110a0bd330a4bb9b332',
#   '2018-03-24 07:54:34',
#   5.13,
#   35.04333337148031),
#  ('00838729460c2110a0bd330a4bb9b332',
#   '2018-03-24 07:54:34',
#   5.13,
#   20.086666742960613),
#  ('00838729460c2110a0bd330a4bb9b332',
#   '2018-03-24 07:54:34',
#   50.0,
#   20.086666742960613),
#  ('00838729460c2110a0bd330a4bb9b332',
#   '2018-03-24 07:54:34',
#   50.0,
#   35.04333337148031),
#  ('00838729460c2110a0bd330a4bb9b332',
#   '2018-03-24 07:54:34',
#   5.13,
#   35.04333337148031),
#  ('00838729460c2110a0bd330a4bb9b332',
#   '2018-03-24 07:54:34',
#   5.13,
#   20.086666742960613),
#  ('0083d9cca92e71d03d298721b572a77b',
#   '2017-05-15 15:24:31',
#   77.63,
#   77.62999725341797),
#  ('0083d9cca92e71d03d298721b572a77b',
#   '2017-05-15 15:24:31',
#   77.63,
#   77.62999725341797),
#  ('0083d9cca92e71d03d298721b572a77b',
#   '2017-05-15 15:24:31',
#   77.63,
#   77.62999725341797),
#  ('0083d9cca92e71d03d298721b572a77b',
#   '2017-05-15 15:24:31',
#   77.63,
#   77.62999725341797),
#  ('008598a4ca17eba904c5fed695cb13be',
#   '2017-07-31 11:23:21',
#   100.34,
#   100.33999633789062),
#  ('008598a4ca17eba904c5fed695cb13be',
#   '2017-07-31 11:23:21',
#   100.34,
#   100.33999633789062),
#  ('008598a4ca17eba904c5fed695cb13be',
#   '2017-07-31 11:23:21',
#   100.34,
#   100.33999633789062),
#  ('008598a4ca17eba904c5fed695cb13be',
#   '2017-07-31 11:23:21',
#   100.34,
#   100.33999633789062),
#  ('008657b86f500495539ffa6d275351b7',
#   '2017-10-08 20:43:44',
#   76.08,
#   76.08000183105469),
#  ('008657b86f500495539ffa6d275351b7',
#   '2017-10-08 20:43:44',
#   76.08,
#   76.08000183105469),
#  ('008657b86f500495539ffa6d275351b7',
#   '2017-10-08 20:43:44',
#   76.08,
#   76.08000183105469),
#  ('008657b86f500495539ffa6d275351b7',
#   '2017-10-08 20:43:44',
#   76.08,
#   76.08000183105469),
#  ('0086b541a59fa554e7953e2d3c285285',
#   '2018-07-26 16:26:56',
#   52.18,
#   52.18000030517578),
#  ('0086b541a59fa554e7953e2d3c285285',
#   '2018-07-26 16:26:56',
#   52.18,
#   52.18000030517578),
#  ('0086b541a59fa554e7953e2d3c285285',
#   '2018-07-26 16:26:56',
#   52.18,
#   52.18000030517578),
#  ('0086b541a59fa554e7953e2d3c285285',
#   '2018-07-26 16:26:56',
#   52.18,
#   52.18000030517578),
#  ('0088393a302a84e57cc69c9d365f5efa',
#   '2017-07-14 12:40:11',
#   66.01,
#   66.01000213623047),
#  ('0088393a302a84e57cc69c9d365f5efa',
#   '2017-07-14 12:40:11',
#   66.01,
#   66.01000213623047),
#  ('0088393a302a84e57cc69c9d365f5efa',
#   '2017-07-14 12:40:11',
#   66.01,
#   66.01000213623047),
#  ('0088393a302a84e57cc69c9d365f5efa',
#   '2017-07-14 12:40:11',
#   66.01,
#   66.01000213623047),
#  ('0088395699ea0fcd459bfbef084997db',
#   '2017-04-02 16:33:30',
#   28.42,
#   28.420000076293945),
#  ('0088395699ea0fcd459bfbef084997db',
#   '2017-04-02 16:33:30',
#   28.42,
#   28.420000076293945),
#  ('0088395699ea0fcd459bfbef084997db',
#   '2017-04-02 16:33:30',
#   28.42,
#   28.420000076293945),
#  ('0088395699ea0fcd459bfbef084997db',
#   '2017-04-02 16:33:30',
#   28.42,
#   28.420000076293945),
#  ('008871f261eb4390ca7a1ded607ea417',
#   '2017-05-13 16:43:19',
#   128.31,
#   128.30999755859375),
#  ('008871f261eb4390ca7a1ded607ea417',
#   '2017-05-13 16:43:19',
#   128.31,
#   128.30999755859375),
#  ('008871f261eb4390ca7a1ded607ea417',
#   '2017-05-13 16:43:19',
#   128.31,
#   128.30999755859375),
#  ('008871f261eb4390ca7a1ded607ea417',
#   '2017-05-13 16:43:19',
#   128.31,
#   128.30999755859375),
#  ('008943f202ed451804dfc1c23248eeb0',
#   '2018-07-28 21:54:44',
#   116.79,
#   116.79000091552734),
#  ('008943f202ed451804dfc1c23248eeb0',
#   '2018-07-28 21:54:44',
#   116.79,
#   116.79000091552734),
#  ('008943f202ed451804dfc1c23248eeb0',
#   '2018-07-28 21:54:44',
#   116.79,
#   116.79000091552734),
#  ('008943f202ed451804dfc1c23248eeb0',
#   '2018-07-28 21:54:44',
#   116.79,
#   116.79000091552734),
#  ('0089c34393989276de67746531e0df21',
#   '2017-10-17 22:31:03',
#   27.33,
#   27.329999923706055),
#  ('0089c34393989276de67746531e0df21',
#   '2017-10-17 22:31:03',
#   27.33,
#   27.329999923706055),
#  ('0089c34393989276de67746531e0df21',
#   '2017-10-17 22:31:03',
#   27.33,
#   27.329999923706055),
#  ('0089c34393989276de67746531e0df21',
#   '2017-10-17 22:31:03',
#   27.33,
#   27.329999923706055),
#  ('008d16b47540f172f75b765d5ea1eed0',
#   '2018-02-05 14:13:56',
#   150.87,
#   150.8699951171875),
#  ('008d16b47540f172f75b765d5ea1eed0',
#   '2018-02-05 14:13:56',
#   150.87,
#   150.8699951171875),
#  ('008d16b47540f172f75b765d5ea1eed0',
#   '2018-02-05 14:13:56',
#   150.87,
#   150.8699951171875),
#  ('008d16b47540f172f75b765d5ea1eed0',
#   '2018-02-05 14:13:56',
#   150.87,
#   150.8699951171875),
#  ('008d7d751e72ae684c0d31bc988b36fb',
#   '2018-03-29 16:22:18',
#   157.77,
#   157.77000427246094),
#  ('008d7d751e72ae684c0d31bc988b36fb',
#   '2018-03-29 16:22:18',
#   157.77,
#   157.77000427246094),
#  ('008d7d751e72ae684c0d31bc988b36fb',
#   '2018-03-29 16:22:18',
#   157.77,
#   157.77000427246094),
#  ('008d7d751e72ae684c0d31bc988b36fb',
#   '2018-03-29 16:22:18',
#   157.77,
#   157.77000427246094),
#  ('008def95c3ec7f58d2cc8f2b1d2c3feb',
#   '2017-08-21 21:09:21',
#   10.98,
#   10.979999542236328),
#  ('008def95c3ec7f58d2cc8f2b1d2c3feb',
#   '2017-08-21 21:09:21',
#   10.98,
#   10.979999542236328),
#  ('008def95c3ec7f58d2cc8f2b1d2c3feb',
#   '2017-08-21 21:09:21',
#   40.16,
#   20.706666310628254),
#  ('008def95c3ec7f58d2cc8f2b1d2c3feb',
#   '2017-08-21 21:09:21',
#   40.16,
#   30.433333079020183),
#  ('008def95c3ec7f58d2cc8f2b1d2c3feb',
#   '2017-08-21 21:09:21',
#   10.98,
#   30.433333079020183),
#  ('008def95c3ec7f58d2cc8f2b1d2c3feb',
#   '2017-08-21 21:09:21',
#   10.98,
#   20.706666310628254),
#  ('008def95c3ec7f58d2cc8f2b1d2c3feb',
#   '2017-08-21 21:09:21',
#   40.16,
#   20.706666310628254),
#  ('008def95c3ec7f58d2cc8f2b1d2c3feb',
#   '2017-08-21 21:09:21',
#   40.16,
#   30.433333079020183),
#  ('008e1bbc8f278134d10d8788a3ca0b7c',
#   '2017-04-11 08:25:26',
#   55.96,
#   55.959999084472656),
#  ('008e1bbc8f278134d10d8788a3ca0b7c',
#   '2017-04-11 08:25:26',
#   55.96,
#   55.959999084472656),
#  ('008e1bbc8f278134d10d8788a3ca0b7c',
#   '2017-04-11 08:25:26',
#   55.96,
#   55.959999084472656),
#  ('008e1bbc8f278134d10d8788a3ca0b7c',
#   '2017-04-11 08:25:26',
#   55.96,
#   55.959999084472656),
#  ('008e75e0f20ba6d6cc41923596b83693',
#   '2018-04-25 12:04:56',
#   82.43,
#   82.43000030517578),
#  ('008e75e0f20ba6d6cc41923596b83693',
#   '2018-04-25 12:04:56',
#   82.43,
#   82.43000030517578),
#  ('008e75e0f20ba6d6cc41923596b83693',
#   '2018-04-25 12:04:56',
#   82.43,
#   82.43000030517578),
#  ('008e75e0f20ba6d6cc41923596b83693',
#   '2018-04-25 12:04:56',
#   82.43,
#   82.43000030517578),
#  ('008f931f2de5414536a04cdd033bea60',
#   '2017-12-14 15:08:06',
#   450.24,
#   450.239990234375),
#  ('008f931f2de5414536a04cdd033bea60',
#   '2017-12-14 15:08:06',
#   450.24,
#   450.239990234375),
#  ('008f931f2de5414536a04cdd033bea60',
#   '2017-12-14 15:08:06',
#   450.24,
#   450.239990234375),
#  ('008f931f2de5414536a04cdd033bea60',
#   '2017-12-14 15:08:06',
#   450.24,
#   450.239990234375),
#  ('009043346db59e970bcad7e5a6e590ca',
#   '2017-09-15 09:24:57',
#   107.87,
#   107.87000274658203),
#  ('009043346db59e970bcad7e5a6e590ca',
#   '2017-09-15 09:24:57',
#   107.87,
#   107.87000274658203),
#  ('009043346db59e970bcad7e5a6e590ca',
#   '2017-09-15 09:24:57',
#   107.87,
#   107.87000274658203),
#  ('009043346db59e970bcad7e5a6e590ca',
#   '2017-09-15 09:24:57',
#   107.87,
#   107.87000274658203),
#  ('0090571a7077aaa71825c98f660695df',
#   '2017-03-12 11:27:09',
#   189.81,
#   189.80999755859375),
#  ('0090571a7077aaa71825c98f660695df',
#   '2017-03-12 11:27:09',
#   189.81,
#   189.80999755859375),
#  ('0090571a7077aaa71825c98f660695df',
#   '2017-03-12 11:27:09',
#   189.81,
#   189.80999755859375),
#  ('0090571a7077aaa71825c98f660695df',
#   '2017-03-12 11:27:09',
#   189.81,
#   189.80999755859375),
#  ('00914220fb44a373f667e19ed450e8df',
#   '2018-08-03 00:26:04',
#   95.65,
#   95.6500015258789),
#  ('00914220fb44a373f667e19ed450e8df',
#   '2018-08-03 00:26:04',
#   95.65,
#   95.6500015258789),
#  ('00914220fb44a373f667e19ed450e8df',
#   '2018-08-03 00:26:04',
#   95.65,
#   95.6500015258789),
#  ('00914220fb44a373f667e19ed450e8df',
#   '2018-08-03 00:26:04',
#   95.65,
#   95.6500015258789),
#  ('0092770b2a1471643d88b60d6b804464',
#   '2017-12-21 15:25:26',
#   198.67,
#   198.6699981689453),
#  ('0092770b2a1471643d88b60d6b804464',
#   '2017-12-21 15:25:26',
#   198.67,
#   198.6699981689453),
#  ('0092770b2a1471643d88b60d6b804464',
#   '2017-12-21 15:25:26',
#   198.67,
#   198.6699981689453),
#  ('0092770b2a1471643d88b60d6b804464',
#   '2017-12-21 15:25:26',
#   198.67,
#   198.6699981689453),
#  ('0092ebfee8043dae610fab832e61acff',
#   '2018-02-22 14:48:09',
#   524.3,
#   524.2999877929688),
#  ('0092ebfee8043dae610fab832e61acff',
#   '2018-02-22 14:48:09',
#   524.3,
#   524.2999877929688),
#  ('0092ebfee8043dae610fab832e61acff',
#   '2018-02-22 14:48:09',
#   524.3,
#   524.2999877929688),
#  ('0092ebfee8043dae610fab832e61acff',
#   '2018-02-22 14:48:09',
#   524.3,
#   524.2999877929688),
#  ('00931b6a1ae01ead1f98d4e1d1547106',
#   '2017-12-09 15:57:50',
#   103.36,
#   103.36000061035156),
#  ('00931b6a1ae01ead1f98d4e1d1547106',
#   '2017-12-09 15:57:50',
#   103.36,
#   103.36000061035156),
#  ('00931b6a1ae01ead1f98d4e1d1547106',
#   '2017-12-09 15:57:50',
#   103.36,
#   103.36000061035156),
#  ('00931b6a1ae01ead1f98d4e1d1547106',
#   '2017-12-09 15:57:50',
#   103.36,
#   103.36000061035156),
#  ('00931eabd5b24b4a2d97ec779d739631',
#   '2017-05-24 03:14:20',
#   65.09,
#   65.08999633789062),
#  ('00931eabd5b24b4a2d97ec779d739631',
#   '2017-05-24 03:14:20',
#   65.09,
#   65.08999633789062),
#  ('00931eabd5b24b4a2d97ec779d739631',
#   '2017-05-24 03:14:20',
#   65.09,
#   65.08999633789062),
#  ('00931eabd5b24b4a2d97ec779d739631',
#   '2017-05-24 03:14:20',
#   65.09,
#   65.08999633789062),
#  ('0093a68265f18be3adbbe054dc4c9295',
#   '2017-07-25 23:39:24',
#   25.97,
#   25.969999313354492),
#  ('0093a68265f18be3adbbe054dc4c9295',
#   '2017-07-25 23:39:24',
#   25.97,
#   25.969999313354492),
#  ('0093a68265f18be3adbbe054dc4c9295',
#   '2017-07-25 23:39:24',
#   25.97,
#   25.969999313354492),
#  ('0093a68265f18be3adbbe054dc4c9295',
#   '2017-07-25 23:39:24',
#   25.97,
#   25.969999313354492),
#  ('0093eadfb5536c158311672bdf418044',
#   '2018-06-26 21:23:04',
#   137.93,
#   137.92999267578125),
#  ('0093eadfb5536c158311672bdf418044',
#   '2018-06-26 21:23:04',
#   137.93,
#   137.92999267578125),
#  ('0093eadfb5536c158311672bdf418044',
#   '2018-06-26 21:23:04',
#   137.93,
#   137.92999267578125),
#  ('0093eadfb5536c158311672bdf418044',
#   '2018-06-26 21:23:04',
#   137.93,
#   137.92999267578125),
#  ('00949af96107ff1f55bc0f09e913686d',
#   '2018-03-31 11:35:12',
#   189.56,
#   189.55999755859375),
#  ('00949af96107ff1f55bc0f09e913686d',
#   '2018-03-31 11:35:12',
#   189.56,
#   189.55999755859375),
#  ('00949af96107ff1f55bc0f09e913686d',
#   '2018-03-31 11:35:12',
#   189.56,
#   189.55999755859375),
#  ('00949af96107ff1f55bc0f09e913686d',
#   '2018-03-31 11:35:12',
#   189.56,
#   189.55999755859375),
#  ('00951234ffc26898cb0f62b8c0e89f88',
#   '2017-10-22 10:53:02',
#   65.09,
#   65.08999633789062),
#  ('00951234ffc26898cb0f62b8c0e89f88',
#   '2017-10-22 10:53:02',
#   65.09,
#   65.08999633789062),
#  ('00951234ffc26898cb0f62b8c0e89f88',
#   '2017-10-22 10:53:02',
#   65.09,
#   65.08999633789062),
#  ('00951234ffc26898cb0f62b8c0e89f88',
#   '2017-10-22 10:53:02',
#   65.09,
#   65.08999633789062),
#  ('0095298db7c70d082c2584d4eb496654',
#   '2017-09-13 18:37:01',
#   299.2,
#   299.20001220703125),
#  ('0095298db7c70d082c2584d4eb496654',
#   '2017-09-13 18:37:01',
#   299.2,
#   299.20001220703125),
#  ('0095298db7c70d082c2584d4eb496654',
#   '2017-09-13 18:37:01',
#   299.2,
#   299.20001220703125),
#  ('0095298db7c70d082c2584d4eb496654',
#   '2017-09-13 18:37:01',
#   299.2,
#   299.20001220703125),
#  ('00953228b409090c774d955f2ab881e5',
#   '2018-08-23 13:46:00',
#   118.35,
#   118.3499984741211),
#  ('00953228b409090c774d955f2ab881e5',
#   '2018-08-23 13:46:00',
#   118.35,
#   118.3499984741211),
#  ('00953228b409090c774d955f2ab881e5',
#   '2018-08-23 13:46:00',
#   118.35,
#   118.3499984741211),
#  ('00953228b409090c774d955f2ab881e5',
#   '2018-08-23 13:46:00',
#   118.35,
#   118.3499984741211),
#  ('009556b29007b7233895402fac956591',
#   '2018-07-21 19:36:39',
#   139.15,
#   139.14999389648438),
#  ('009556b29007b7233895402fac956591',
#   '2018-07-21 19:36:39',
#   139.15,
#   139.14999389648438),
#  ('009556b29007b7233895402fac956591',
#   '2018-07-21 19:36:39',
#   139.15,
#   139.14999389648438),
#  ('009556b29007b7233895402fac956591',
#   '2018-07-21 19:36:39',
#   139.15,
#   139.14999389648438),
#  ('0095d34ddb16f0d0776fc9f2a341dfcd',
#   '2018-01-13 09:28:26',
#   257.3,
#   257.29998779296875),
#  ('0095d34ddb16f0d0776fc9f2a341dfcd',
#   '2018-01-13 09:28:26',
#   257.3,
#   257.29998779296875),
#  ('0095d34ddb16f0d0776fc9f2a341dfcd',
#   '2018-01-13 09:28:26',
#   257.3,
#   257.29998779296875),
#  ('0095d34ddb16f0d0776fc9f2a341dfcd',
#   '2018-01-13 09:28:26',
#   257.3,
#   257.29998779296875),
#  ('0096dd625383caa8afe2c028018bf4ce', '2018-04-11 13:27:29', 100.0, 100.0),
#  ('0096dd625383caa8afe2c028018bf4ce', '2018-04-11 13:27:29', 100.0, 100.0),
#  ('0096dd625383caa8afe2c028018bf4ce',
#   '2018-04-11 13:27:29',
#   421.37,
#   207.12333170572916),
#  ('0096dd625383caa8afe2c028018bf4ce',
#   '2018-04-11 13:27:29',
#   421.37,
#   314.2466634114583),
#  ('0096dd625383caa8afe2c028018bf4ce',
#   '2018-04-11 13:27:29',
#   421.37,
#   421.3699951171875),
#  ('0096dd625383caa8afe2c028018bf4ce',
#   '2018-04-11 13:27:29',
#   421.37,
#   421.3699951171875),
#  ('0096dd625383caa8afe2c028018bf4ce',
#   '2018-04-11 13:27:29',
#   100.0,
#   314.2466634114583),
#  ('0096dd625383caa8afe2c028018bf4ce',
#   '2018-04-11 13:27:29',
#   100.0,
#   207.12333170572916),
#  ('0097c5abeb126a90646370f4a1cf3d93',
#   '2018-06-04 23:59:23',
#   39.67,
#   39.66999816894531),
#  ('0097c5abeb126a90646370f4a1cf3d93',
#   '2018-06-04 23:59:23',
#   39.67,
#   39.66999816894531),
#  ('0097c5abeb126a90646370f4a1cf3d93',
#   '2018-06-04 23:59:23',
#   9.01,
#   29.44999885559082),
#  ('0097c5abeb126a90646370f4a1cf3d93',
#   '2018-06-04 23:59:23',
#   100.0,
#   49.55999946594238),
#  ('0097c5abeb126a90646370f4a1cf3d93',
#   '2018-06-04 23:59:23',
#   9.01,
#   39.34000015258789),
#  ('0097c5abeb126a90646370f4a1cf3d93',
#   '2018-06-04 23:59:23',
#   100.0,
#   69.67000007629395),
#  ('0097c5abeb126a90646370f4a1cf3d93',
#   '2018-06-04 23:59:23',
#   39.67,
#   49.55999946594238),
#  ('0097c5abeb126a90646370f4a1cf3d93',
#   '2018-06-04 23:59:23',
#   100.0,
#   79.88999938964844),
#  ...]

# %% [markdown]
# #  Calculate the cumulative sales per month for each year.

# %%
 query = """ select years, months, payment, sum(payment)
 over(order by years, months) cumulative_sales from
 (select year(orders.order_purchase_timestamp) as years,
 month(orders.order_purchase_timestamp) as months,
 round(sum(payments.payment_value),1) as payment from orders join payments
 on orders.order_id = payments.order_id
 group by years, months order by years, months) as a
"""

cur.execute(query)

data = cur.fetchall()
data
# line chart#
# Out:
# [(2016, 9, 1009.0, 1009.0),
#  (2016, 10, 236361.9, 237370.9),
#  (2016, 12, 78.5, 237449.4),
#  (2017, 1, 553952.2, 791401.6),
#  (2017, 2, 1167632.0, 1959033.6),
#  (2017, 3, 1799454.4, 3758488.0),
#  (2017, 4, 1671152.1, 5429640.1),
#  (2017, 5, 2371675.3, 7801315.399999999),
#  (2017, 6, 2045105.5, 9846420.899999999),
#  (2017, 7, 2369531.7, 12215952.599999998),
#  (2017, 8, 2697585.3, 14913537.899999999),
#  (2017, 9, 2911049.8, 17824587.7),
#  (2017, 10, 3118711.5, 20943299.2),
#  (2017, 11, 4779531.2, 25722830.4),
#  (2017, 12, 3513605.9, 29236436.299999997),
#  (2018, 1, 4460016.7, 33696453.0),
#  (2018, 2, 3969853.4, 37666306.4),
#  (2018, 3, 4638608.5, 42304914.9),
#  (2018, 4, 4643141.9, 46948056.8),
#  (2018, 5, 4615928.6, 51563985.4),
#  (2018, 6, 4095522.0, 55659507.4),
#  (2018, 7, 4266163.0, 59925670.4),
#  (2018, 8, 4089701.3, 64015371.699999996),
#  (2018, 9, 17758.2, 64033129.9),
#  (2018, 10, 2358.7, 64035488.6)]

# %% [markdown]
# # Calculate the year-over-year growth rate of total sales.

# %%
 query = """with a as(select year(orders.order_purchase_timestamp) as years,
 round(sum(payments.payment_value),1) as payment from orders join payments
 
 on orders.order_id = payments.order_id
 group by years order by years)

 select years,((payment - lag(payment, 1) over(order by years))/lag(payment, 1) over(order by years))*100 from a
"""

cur.execute(query)

data = cur.fetchall()
data
df = pd.DataFrame(data, columns= ["years","yoy % growth"])
df
# line chart#
# Out:
#    years  yoy % growth
# 0   2016           NaN
# 1   2017  12112.701696
# 2   2018     20.000924

# %% [markdown]
# # Calculate the retention rate of customers, defined as the percentage of customers who make another purchase within 6 months of their first purchase.

# %%
 query = """with a as(select customers.customer_id,
 min(orders.order_purchase_timestamp) first_order
 from customers join orders
 on customers.customer_id = orders.customer_id
 group by customers.customer_id),

 b as (select a.customer_id, count(distinct orders.order_purchase_timestamp) next_order
 from a join orders
 on orders.customer_id = a.customer_id
 and orders.order_purchase_timestamp > first_order
 and orders.order_purchase_timestamp <
 date_add(first_order, interval 6 month)
 group by a.customer_id)

 select 100 * (count( distinct a.customer_id)/count(distinct b.customer_id))
 from a left join b
 on a.customer_id = b.customer_id
 
"""

cur.execute(query)

data = cur.fetchall()
data
# Out:
# [(None,)]

# %% [markdown]
# # Identify the top 3 customers who spent the most money in each year.

# %%
 query = """select years, customer_id, payment, d_rank
 from 
 (select year(orders.order_purchase_timestamp) years,
 orders.customer_id,
 sum(payments.payment_value) payment,
 dense_rank() over(partition by year(orders.order_purchase_timestamp)
 order by sum(payments.payment_value) desc) d_rank
 from orders join payments
 on payments.ordeR_id = orders.order_id
 group by year(orders.order_purchase_timestamp),
 orders.customer_id) as a
 where d_rank <= 3
 
"""

cur.execute(query)

data = cur.fetchall()
df = pd.DataFrame(data, columns = ["years", "id", "payment", "rank"])
sns.barplot(x = "id" , y = "payment", data = df, hue = "years")
plt.xticks(rotation = 90)
plt.show()
